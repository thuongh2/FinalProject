# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # DỮ LIỆU

# %% [markdown]
# ## GIÁ CÀ PHÊ

# %%
df_coffee = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data/gia_ca_phe_den_2023.csv', encoding='ISO-8859-1')
df_coffee.head()
# Out:
#        date    price
# 0  1/2/2007  21600.0
# 1  1/3/2007  22000.0
# 2  1/4/2007  21700.0
# 3  1/5/2007  22000.0
# 4  1/6/2007  22000.0

# %%
df_coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6208 entries, 0 to 6207
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6208 non-null   object
#  1   price   6208 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 97.1+ KB

# %%
df_coffee['date'] = pd.to_datetime(df_coffee['date'])
df_coffee.set_index('date', inplace=True)

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_coffee, x=df_coffee.index, y='price')
plt.title('Biểu đồ giá cà phê tại Đăk Lăk')
plt.xlabel('Ngày')
plt.ylabel('Giá (đồng/kg)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## XUẤT KHẨU VÀ PHÊ

# %%
df_coffee_export = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data/gia_xuat_khau_ca_phe.csv', encoding='ISO-8859-1')
df_coffee_export.head()
# Out:
#        date  Luong (nghin tan)  Kim ngach (trieu USD)  Trieu USD/ Nghin tan
# 0  1/1/2009             151.13                 232.00              1.535102
# 1  2/1/2009             154.40                 236.62              1.532513
# 2  3/1/2009             137.02                 199.81              1.458254
# 3  4/1/2009             123.77                 180.16              1.455603
# 4  5/1/2009              93.09                 134.10              1.440541

# %%
df_coffee_export['date'] = pd.to_datetime(df_coffee_export['date'])
df_coffee_export.set_index('date', inplace=True)

# %% [markdown]
# ### Xử lý outlier

# %%
df_coffee_export[['Trieu USD/ Nghin tan']].boxplot()
# Out:
# <Axes: >

# %%
# Tính toán ngưỡng cho outlier sử dụng IQR
Q1 = df_coffee_export['Trieu USD/ Nghin tan'].quantile(0.25)
Q3 = df_coffee_export['Trieu USD/ Nghin tan'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Xác định các dòng dữ liệu có giá trị nằm ngoài ngưỡng
outliers = df_coffee_export[(df_coffee_export['Trieu USD/ Nghin tan'] < lower_bound) | (df_coffee_export['Trieu USD/ Nghin tan'] > upper_bound)]
print("Số lượng outlier:", len(outliers))
# Out:
# Số lượng outlier: 6

# %%
# Kiểm tra và thay đổi giá trị nếu nó nằm ngoài ngưỡng
df_coffee_export.at[df_coffee_export.index[0], 'Trieu USD/ Nghin tan'] = min(max(df_coffee_export.iloc[0]['Trieu USD/ Nghin tan'], lower_bound), upper_bound)

# Thay thế giá trị của outlier bằng giá trị trước đó
for index, row in outliers.iterrows():
    previous_date_index = df_coffee_export.index.get_loc(index) - 1
    if previous_date_index >= 0:
        previous_date = df_coffee_export.index[previous_date_index]
        previous_value = df_coffee_export.loc[previous_date, 'Trieu USD/ Nghin tan']
        df_coffee_export.at[index, 'Trieu USD/ Nghin tan'] = previous_value

# %%
df_coffee_export[['Trieu USD/ Nghin tan']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### Fill dữ liệu ngày bị thiếu

# %%
idx = pd.date_range(df_coffee_export.index.min(), df_coffee_export.index.max())
df_coffee_export = df_coffee_export.reindex(idx)

# %%
df_coffee_export.fillna(method='ffill', inplace=True)
df_coffee_export.head()
# Out:
#             Luong (nghin tan)  Kim ngach (trieu USD)  Trieu USD/ Nghin tan
# 2009-01-01             151.13                  232.0              1.535102
# 2009-01-02             151.13                  232.0              1.535102
# 2009-01-03             151.13                  232.0              1.535102
# 2009-01-04             151.13                  232.0              1.535102
# 2009-01-05             151.13                  232.0              1.535102

# %% [markdown]
# ### Merge dữ liệu xuất khẩu vào giá cà phê

# %%
start_date = df_coffee_export.index.min()
df_coffee_filtered = df_coffee.loc[start_date:]

df_merged_coffee_export = pd.merge(df_coffee_filtered, df_coffee_export[['Trieu USD/ Nghin tan']], left_index=True, right_index=True, how='left')
df_merged_coffee_export['Trieu USD/ Nghin tan'] = df_merged_coffee_export['Trieu USD/ Nghin tan'].ffill()

print(df_merged_coffee_export.tail())
# Out:
#               price  Trieu USD/ Nghin tan
# date
# 2023-12-27  68000.0              2.892161
# 2023-12-28  68850.0              2.892161
# 2023-12-29  70000.0              2.892161
# 2023-12-30  68200.0              2.892161
# 2023-12-31  68200.0              2.892161

# %% [markdown]
# ## GIÁ XĂNG

# %%
df_gasoline = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data/gia_xang.csv', encoding='ISO-8859-1')
df_gasoline.tail()
# Out:
#            date  RON 95-III
# 170    2/5/2024       24.95
# 171    9/5/2024       23.54
# 172  16/05/2024       23.13
# 173  23/05/2024       23.21
# 174  29/05/2024       23.21

# %% [markdown]
# ### Xử lý outlier

# %%
df_gasoline[['RON 95-III']].boxplot()
# Out:
# <Axes: >

# %%
# Tính toán ngưỡng cho outlier sử dụng IQR
Q1 = df_gasoline['RON 95-III'].quantile(0.25)
Q3 = df_gasoline['RON 95-III'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Xác định các dòng dữ liệu có giá trị nằm ngoài ngưỡng
outliers = df_gasoline[(df_gasoline['RON 95-III'] < lower_bound) | (df_gasoline['RON 95-III'] > upper_bound)]
print("Số lượng outlier:", len(outliers))
# Out:
# Số lượng outlier: 14

# %%
# Kiểm tra và thay đổi giá trị nếu nó nằm ngoài ngưỡng
df_gasoline.at[df_gasoline.index[0], 'RON 95-III'] = min(max(df_gasoline.iloc[0]['RON 95-III'], lower_bound), upper_bound)

# Thay thế giá trị của outlier bằng giá trị trước đó
for index, row in outliers.iterrows():
    previous_date_index = df_gasoline.index.get_loc(index) - 1
    if previous_date_index >= 0:
        previous_date = df_gasoline.index[previous_date_index]
        previous_value = df_gasoline.loc[previous_date, 'RON 95-III']
        df_gasoline.at[index, 'RON 95-III'] = previous_value

# %%
df_gasoline[['RON 95-III']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### Fill dữ liệu ngày bị thiếu

# %%
df_gasoline['date'] = pd.to_datetime(df_gasoline['date'])
df_gasoline.set_index('date', inplace=True)
# Out:
# <ipython-input-84-2ca4586e2886>:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_gasoline['date'] = pd.to_datetime(df_gasoline['date'])

# %%
idx = pd.date_range(df_gasoline.index.min(), df_gasoline.index.max())
df_gasoline = df_gasoline.reindex(idx)
df_gasoline.fillna(method='ffill', inplace=True)

# %% [markdown]
# ### Merge dữ liệu xăng với cà phê

# %%
start_date = df_gasoline.index.min()
df_coffee_filtered = df_coffee.loc[start_date:]

df_merged_gasoline = pd.merge(df_coffee_filtered, df_gasoline[['RON 95-III']], left_index=True, right_index=True, how='left')
df_merged_gasoline['RON 95-III'] = df_merged_gasoline['RON 95-III'].ffill()

print(df_merged_gasoline.tail())
# Out:
#               price  RON 95-III
# date
# 2023-12-27  68000.0       22.14
# 2023-12-28  68850.0       22.14
# 2023-12-29  70000.0       22.14
# 2023-12-30  68200.0       22.14
# 2023-12-31  68200.0       22.14

# %% [markdown]
# # Mô hình dự đoán

# %% [markdown]
# ## Giá cà phê kết hợp giá xuất khẩu

# %% [markdown]
# ### Xây dựng mô hình

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), :])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
df_coffee_export_predictions = df_merged_coffee_export.copy()

scaler_price = MinMaxScaler(feature_range=(0, 1))
scaled_price = scaler_price.fit_transform(df_coffee_export_predictions[['price']])

scaler_export = MinMaxScaler(feature_range=(0, 1))
scaled_export = scaler_export.fit_transform(df_coffee_export_predictions[['Trieu USD/ Nghin tan']])

scaled_data = np.concatenate((scaled_price, scaled_export), axis=1)

# %%
seq_length = 30
X, y = create_sequences(scaled_data, seq_length)

# %%
X.shape, y.shape
# Out:
# ((5448, 30, 2), (5448,))

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print("Kích thước tập huấn luyện:", X_train.shape, y_train.shape)
print("Kích thước tập kiểm tra:", X_test.shape, y_test.shape)
# Out:
# Kích thước tập huấn luyện: (4358, 30, 2) (4358,)
# Kích thước tập kiểm tra: (1090, 30, 2) (1090,)

# %%
model_coffee_export = Sequential()
model_coffee_export.add(Bidirectional(LSTM(units=128, return_sequences=True), input_shape=(seq_length, 2)))
model_coffee_export.add(Dropout(0.2))
model_coffee_export.add(Bidirectional(LSTM(units=64), input_shape=(seq_length, 1)))
model_coffee_export.add(Dropout(0.2))
model_coffee_export.add(Dense(units=64, activation='tanh'))
model_coffee_export.add(Dense(units=1))

# %%
model_coffee_export.compile(optimizer='adam', loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# %%
model_coffee_export.fit(X_train, y_train, epochs=50, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 69/69 [==============================] - 21s 190ms/step - loss: 0.0061
# Epoch 2/50
# 69/69 [==============================] - 13s 184ms/step - loss: 8.7487e-04
# Epoch 3/50
# 69/69 [==============================] - 12s 181ms/step - loss: 7.4901e-04
# Epoch 4/50
# 69/69 [==============================] - 12s 180ms/step - loss: 5.9958e-04
# Epoch 5/50
# 69/69 [==============================] - 14s 196ms/step - loss: 5.4468e-04
# Epoch 6/50
# 69/69 [==============================] - 13s 183ms/step - loss: 4.7382e-04
# Epoch 7/50
# 69/69 [==============================] - 14s 203ms/step - loss: 4.9126e-04
# Epoch 8/50
# 69/69 [==============================] - 13s 185ms/step - loss: 3.9854e-04
# Epoch 9/50
# 69/69 [==============================] - 13s 184ms/step - loss: 3.6734e-04
# Epoch 10/50
# 69/69 [==============================] - 13s 193ms/step - loss: 3.3763e-04
# Epoch 11/50
# 69/69 [==============================] - 13s 184ms/step - loss: 3.1087e-04
# Epoch 12/50
# 69/69 [==============================] - 12s 169ms/step - loss: 2.9714e-04
# Epoch 13/50
# 69/69 [==============================] - 12s 170ms/step - loss: 3.0983e-04
# Epoch 14/50
# 69/69 [==============================] - 13s 183ms/step - loss: 3.1876e-04
# Epoch 15/50
# 69/69 [==============================] - 13s 184ms/step - loss: 2.7351e-04
# Epoch 16/50
# 69/69 [==============================] - 13s 184ms/step - loss: 2.5084e-04
# Epoch 17/50
# 69/69 [==============================] - 13s 183ms/step - loss: 2.4030e-04
# Epoch 18/50
# 69/69 [==============================] - 13s 186ms/step - loss: 2.2630e-04
# Epoch 19/50
# 69/69 [==============================] - 13s 183ms/step - loss: 2.4121e-04
# Epoch 20/50
# 69/69 [==============================] - 12s 179ms/step - loss: 2.3718e-04
# Epoch 21/50
# 69/69 [==============================] - 12s 181ms/step - loss: 2.2113e-04
# Epoch 22/50
# 69/69 [==============================] - 13s 183ms/step - loss: 2.4414e-04
# Epoch 23/50
# 69/69 [==============================] - 12s 179ms/step - loss: 2.1923e-04
# Epoch 24/50
# 69/69 [==============================] - 12s 170ms/step - loss: 2.2333e-04
# Epoch 25/50
# 69/69 [==============================] - 12s 174ms/step - loss: 2.3289e-04
# Epoch 26/50
# 69/69 [==============================] - 13s 184ms/step - loss: 1.9728e-04
# Epoch 27/50
# 69/69 [==============================] - 13s 183ms/step - loss: 2.1281e-04
# Epoch 28/50
# 69/69 [==============================] - 14s 208ms/step - loss: 2.0838e-04
# Epoch 29/50
# 69/69 [==============================] - 13s 184ms/step - loss: 2.1172e-04
# Epoch 30/50
# 69/69 [==============================] - 13s 184ms/step - loss: 1.9499e-04
# Epoch 31/50
# 69/69 [==============================] - 13s 184ms/step - loss: 1.9788e-04
# Epoch 32/50
# 69/69 [==============================] - 13s 183ms/step - loss: 1.9240e-04
# Epoch 33/50
# 69/69 [==============================] - 13s 184ms/step - loss: 1.8363e-04
# Epoch 34/50
# 69/69 [==============================] - 12s 177ms/step - loss: 2.0063e-04
# Epoch 35/50
# 69/69 [==============================] - 12s 168ms/step - loss: 2.1530e-04
# Epoch 36/50
# 69/69 [==============================] - 12s 178ms/step - loss: 1.8729e-04
# Epoch 37/50
# 69/69 [==============================] - 13s 182ms/step - loss: 1.9915e-04
# Epoch 38/50
# 69/69 [==============================] - 13s 183ms/step - loss: 2.1484e-04

# %% [markdown]
# ### Dự đoán trên tập train

# %%
train_predictions = model_coffee_export.predict(X_train)
# Out:
# 137/137 [==============================] - 8s 50ms/step

# %%
train_predictions = scaler_price.inverse_transform(train_predictions)
y_train = scaler_price.inverse_transform(y_train.reshape(-1, 1))

# %%
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_mape = calculate_mape(y_train, train_predictions)

print(f'Training RMSE: {train_rmse:.2f}')
print(f'Training MAPE: {train_mape:.2f}%')
# Out:
# Training RMSE: 572.09
# Training MAPE: 1.17%

# %%
dates = df_coffee.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_train)], y=y_train.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(train_predictions)], y=train_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập huấn luyện (mô hình BiLSTM, dữ liệu giá cà phê và xuất khẩu)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9f10cb0d-9750-4964-8f8e-05e1dc65f3d4" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f10cb0d-9750-4964-8f8e-05e1dc65f3d4")) {                    Plotly.newPlot(                        "9f10cb0d-9750-4964-8f8e-05e1dc65f3d4",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2007-01-02T00:00:00","2007-01-03T00:00:00","2007-01-04T00:00:00","2007-01-05T00:00:00","2007-01-06T00:00:00","2007-01-07T00:00:00","2007-01-08T00:00:00","2007-01-09T00:00:00","2007-01-10T00:00:00","2007-01-11T00:00:00","2007-01-12T00:00:00","2007-01-13T00:00:00","2007-01-14T00:00:00","2007-01-15T00:00:00","2007-01-16T00:00:00","2007-01-17T00:00:00","2007-01-18T00:00:00","2007-01-19T00:00:00","2007-01-20T00:00:00","2007-01-21T00:00:00","2007-01-22T00:00:00","2007-01-23T00:00:00","2007-01-24T00:00:00","2007-01-25T00:00:00","2007-01-26T00:00:00","2007-01-27T00:00:00","2007-01-28T00:00:00","2007-01-29T00:00:00","2007-01-30T00:00:00","2007-01-31T00:00:00","2007-02-01T00:00:00","2007-02-02T00:00:00","2007-02-03T00:00:00","2007-02-04T00:00:00","2007-02-05T00:00:00","2007-02-06T00:00:00","2007-02-07T00:00:00","2007-02-08T00:00:00","2007-02-09T00:00:00","2007-02-10T00:00:00","2007-02-11T00:00:00","2007-02-12T00:00:00","2007-02-13T00:00:00","2007-02-14T00:00:00","2007-02-15T00:00:00","2007-02-16T00:00:00","2007-02-17T00:00:00","2007-02-18T00:00:00","2007-02-19T00:00:00","2007-02-20T00:00:00","2007-02-21T00:00:00","2007-02-22T00:00:00","2007-02-23T00:00:00","2007-02-24T00:00:00","2007-02-25T00:00:00","2007-02-26T00:00:00","2007-02-27T00:00:00","2007-02-28T00:00:00","2007-03-01T00:00:00","2007-03-02T00:00:00","2007-03-03T00:00:00","2007-03-04T00:00:00","2007-03-05T00:00:00","2007-03-06T00:00:00","2007-03-07T00:00:00","2007-03-08T00:00:00","2007-03-09T00:00:00","2007-03-10T00:00:00","2007-03-11T00:00:00","2007-03-12T00:00:00","2007-03-13T00:00:00","2007-03-14T00:00:00","2007-03-15T00:00:00","2007-03-16T00:00:00","2007-03-17T00:00:00","2007-03-18T00:00:00","2007-03-19T00:00:00","2007-03-20T00:00:00","2007-03-21T00:00:00","2007-03-22T00:00:00","2007-03-23T00:00:00","2007-03-24T00:00:00","2007-03-25T00:00:00","2007-03-26T00:00:00","2007-03-27T00:00:00","2007-03-28T00:00:00","2007-03-29T00:00:00","2007-03-30T00:00:00","2007-03-31T00:00:00","2007-04-01T00:00:00","2007-04-02T00:00:00","2007-04-03T00:00:00","2007-04-04T00:00:00","2007-04-05T00:00:00","2007-04-06T00:00:00","2007-04-07T00:00:00","2007-04-08T00:00:00","2007-04-09T00:00:00","2007-04-10T00:00:00","2007-04-11T00:00:00","2007-04-12T00:00:00","2007-04-13T00:00:00","2007-04-14T00:00:00","2007-04-15T00:00:00","2007-04-16T00:00:00","2007-04-17T00:00:00","2007-04-18T00:00:00","2007-04-19T00:00:00","2007-04-20T00:00:00","2007-04-21T00:00:00","2007-04-22T00:00:00","2007-04-23T00:00:00","2007-04-24T00:00:00","2007-04-25T00:00:00","2007-04-26T00:00:00","2007-04-27T00:00:00","2007-04-28T00:00:00","2007-04-29T00:00:00","2007-04-30T00:00:00","2007-05-01T00:00:00","2007-05-02T00:00:00","2007-05-03T00:00:00","2007-05-04T00:00:00","2007-05-05T00:00:00","2007-05-06T00:00:00","2007-05-07T00:00:00","2007-05-08T00:00:00","2007-05-09T00:00:00","2007-05-10T00:00:00","2007-05-11T00:00:00","2007-05-12T00:00:00","2007-05-13T00:00:00","2007-05-14T00:00:00","2007-05-15T00:00:00","2007-05-16T00:00:00","2007-05-17T00:00:00","2007-05-18T00:00:00","2007-05-19T00:00:00","2007-05-20T00:00:00","2007-05-21T00:00:00","2007-05-22T00:00:00","2007-05-23T00:00:00","2007-05-24T00:00:00","2007-05-25T00:00:00","2007-05-26T00:00:00","2007-05-27T00:00:00","2007-05-28T00:00:00","2007-05-29T00:00:00","2007-05-30T00:00:00","2007-05-31T00:00:00","2007-06-01T00:00:00","2007-06-02T00:00:00","2007-06-03T00 ...

# %%
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_mape = calculate_mape(y_train, train_predictions)

print(f'Training RMSE: {train_rmse:.2f}')
print(f'Training MAPE: {train_mape:.2f}%')
# Out:
# Training RMSE: 572.09
# Training MAPE: 1.17%

# %% [markdown]
# ### Dự đoán trên tập test

# %%
test_predictions = model_coffee_export.predict(X_test)
# Out:
# 35/35 [==============================] - 1s 36ms/step

# %%
test_predictions = scaler_price.inverse_transform(test_predictions)
y_test = scaler_price.inverse_transform(y_test.reshape(-1, 1))

# %%
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
test_mape = calculate_mape(y_test, test_predictions)

print(f'Testing RMSE: {test_rmse:.2f}')
print(f'Testing MAPE: {test_mape:.2f}%')
# Out:
# Testing RMSE: 770.61
# Testing MAPE: 1.19%

# %%
dates = df_coffee.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_test)], y=y_test.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(test_predictions)], y=test_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập kiểm tra (mô hình BiLSTM, dữ liệu giá cà phê và xuất khẩu)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a3d90e5f-b526-4b5e-8821-c583049a7397" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3d90e5f-b526-4b5e-8821-c583049a7397")) {                    Plotly.newPlot(                        "a3d90e5f-b526-4b5e-8821-c583049a7397",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2007-01-02T00:00:00","2007-01-03T00:00:00","2007-01-04T00:00:00","2007-01-05T00:00:00","2007-01-06T00:00:00","2007-01-07T00:00:00","2007-01-08T00:00:00","2007-01-09T00:00:00","2007-01-10T00:00:00","2007-01-11T00:00:00","2007-01-12T00:00:00","2007-01-13T00:00:00","2007-01-14T00:00:00","2007-01-15T00:00:00","2007-01-16T00:00:00","2007-01-17T00:00:00","2007-01-18T00:00:00","2007-01-19T00:00:00","2007-01-20T00:00:00","2007-01-21T00:00:00","2007-01-22T00:00:00","2007-01-23T00:00:00","2007-01-24T00:00:00","2007-01-25T00:00:00","2007-01-26T00:00:00","2007-01-27T00:00:00","2007-01-28T00:00:00","2007-01-29T00:00:00","2007-01-30T00:00:00","2007-01-31T00:00:00","2007-02-01T00:00:00","2007-02-02T00:00:00","2007-02-03T00:00:00","2007-02-04T00:00:00","2007-02-05T00:00:00","2007-02-06T00:00:00","2007-02-07T00:00:00","2007-02-08T00:00:00","2007-02-09T00:00:00","2007-02-10T00:00:00","2007-02-11T00:00:00","2007-02-12T00:00:00","2007-02-13T00:00:00","2007-02-14T00:00:00","2007-02-15T00:00:00","2007-02-16T00:00:00","2007-02-17T00:00:00","2007-02-18T00:00:00","2007-02-19T00:00:00","2007-02-20T00:00:00","2007-02-21T00:00:00","2007-02-22T00:00:00","2007-02-23T00:00:00","2007-02-24T00:00:00","2007-02-25T00:00:00","2007-02-26T00:00:00","2007-02-27T00:00:00","2007-02-28T00:00:00","2007-03-01T00:00:00","2007-03-02T00:00:00","2007-03-03T00:00:00","2007-03-04T00:00:00","2007-03-05T00:00:00","2007-03-06T00:00:00","2007-03-07T00:00:00","2007-03-08T00:00:00","2007-03-09T00:00:00","2007-03-10T00:00:00","2007-03-11T00:00:00","2007-03-12T00:00:00","2007-03-13T00:00:00","2007-03-14T00:00:00","2007-03-15T00:00:00","2007-03-16T00:00:00","2007-03-17T00:00:00","2007-03-18T00:00:00","2007-03-19T00:00:00","2007-03-20T00:00:00","2007-03-21T00:00:00","2007-03-22T00:00:00","2007-03-23T00:00:00","2007-03-24T00:00:00","2007-03-25T00:00:00","2007-03-26T00:00:00","2007-03-27T00:00:00","2007-03-28T00:00:00","2007-03-29T00:00:00","2007-03-30T00:00:00","2007-03-31T00:00:00","2007-04-01T00:00:00","2007-04-02T00:00:00","2007-04-03T00:00:00","2007-04-04T00:00:00","2007-04-05T00:00:00","2007-04-06T00:00:00","2007-04-07T00:00:00","2007-04-08T00:00:00","2007-04-09T00:00:00","2007-04-10T00:00:00","2007-04-11T00:00:00","2007-04-12T00:00:00","2007-04-13T00:00:00","2007-04-14T00:00:00","2007-04-15T00:00:00","2007-04-16T00:00:00","2007-04-17T00:00:00","2007-04-18T00:00:00","2007-04-19T00:00:00","2007-04-20T00:00:00","2007-04-21T00:00:00","2007-04-22T00:00:00","2007-04-23T00:00:00","2007-04-24T00:00:00","2007-04-25T00:00:00","2007-04-26T00:00:00","2007-04-27T00:00:00","2007-04-28T00:00:00","2007-04-29T00:00:00","2007-04-30T00:00:00","2007-05-01T00:00:00","2007-05-02T00:00:00","2007-05-03T00:00:00","2007-05-04T00:00:00","2007-05-05T00:00:00","2007-05-06T00:00:00","2007-05-07T00:00:00","2007-05-08T00:00:00","2007-05-09T00:00:00","2007-05-10T00:00:00","2007-05-11T00:00:00","2007-05-12T00:00:00","2007-05-13T00:00:00","2007-05-14T00:00:00","2007-05-15T00:00:00","2007-05-16T00:00:00","2007-05-17T00:00:00","2007-05-18T00:00:00","2007-05-19T00:00:00","2007-05-20T00:00:00","2007-05-21T00:00:00","2007-05-22T00:00:00","2007-05-23T00:00:00","2007-05-24T00:00:00","2007-05-25T00:00:00","2007-05-26T00:00:00","2007-05-27T00:00:00","2007-05-28T00:00:00","2007-05-29T00:00:00","2007-05-30T00:00:00","2007-05-31T00:00:00","2007-06-01T00:00:00","2007-06-02T00:00:00","2007-06-03T00 ...

# %% [markdown]
# ### Đánh giá kết quả

# %%
results = pd.DataFrame({
    '': ['Train', 'Test'],
    'RMSE': [train_rmse, test_rmse],
    'MAPE (%)': [train_mape, test_mape]
})
results = results.round(2)

print(results)
# Out:
#             RMSE  MAPE (%)
# 0  Train  572.09      1.17
# 1   Test  770.61      1.19

# %% [markdown]
# ### Lưu mô hình

# %%
# from tensorflow.keras.models import load_model

# model_coffee_export.save('/content/drive/MyDrive/KLTN/SavedModels/LSTM_multivariate_coffee_export.h5')

# %% [markdown]
# ## Giá cà phê kết hợp giá xăng

# %% [markdown]
# ### Xây dựng mô hình

# %%
# Preprocess data
scaler_price = MinMaxScaler(feature_range=(0, 1))
scaled_price = scaler_price.fit_transform(df_merged_gasoline[['price']])

scaler_export = MinMaxScaler(feature_range=(0, 1))
scaled_export = scaler_export.fit_transform(df_merged_gasoline[['RON 95-III']])

scaled_data = np.concatenate((scaled_price, scaled_export), axis=1)

# %%
seq_length = 30
X, y = create_sequences(scaled_data, seq_length)

# %%
X.shape, y.shape
# Out:
# ((1928, 30, 2), (1928,))

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print("Kích thước tập huấn luyện:", X_train.shape, y_train.shape)
print("Kích thước tập kiểm tra:", X_test.shape, y_test.shape)
# Out:
# Kích thước tập huấn luyện: (1542, 30, 2) (1542,)
# Kích thước tập kiểm tra: (386, 30, 2) (386,)

# %%
model_gasoline = Sequential()
model_gasoline.add(Bidirectional(LSTM(units=128, return_sequences=True), input_shape=(seq_length, 2)))
model_gasoline.add(Dropout(0.2))
model_gasoline.add(Bidirectional(LSTM(units=64), input_shape=(seq_length, 1)))
model_gasoline.add(Dropout(0.2))
model_gasoline.add(Dense(units=64, activation='tanh'))
model_gasoline.add(Dense(units=1))

# %%
model_gasoline.compile(optimizer='adam', loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# %%
model_gasoline.fit(X_train, y_train, epochs=50, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 25/25 [==============================] - 14s 163ms/step - loss: 0.0062
# Epoch 2/50
# 25/25 [==============================] - 4s 163ms/step - loss: 8.7213e-04
# Epoch 3/50
# 25/25 [==============================] - 6s 232ms/step - loss: 6.3165e-04
# Epoch 4/50
# 25/25 [==============================] - 4s 160ms/step - loss: 4.9017e-04
# Epoch 5/50
# 25/25 [==============================] - 4s 161ms/step - loss: 4.2962e-04
# Epoch 6/50
# 25/25 [==============================] - 6s 228ms/step - loss: 4.1643e-04
# Epoch 7/50
# 25/25 [==============================] - 4s 161ms/step - loss: 3.5611e-04
# Epoch 8/50
# 25/25 [==============================] - 4s 162ms/step - loss: 3.5867e-04
# Epoch 9/50
# 25/25 [==============================] - 6s 234ms/step - loss: 3.9890e-04
# Epoch 10/50
# 25/25 [==============================] - 4s 160ms/step - loss: 2.9298e-04
# Epoch 11/50
# 25/25 [==============================] - 4s 161ms/step - loss: 3.0821e-04
# Epoch 12/50
# 25/25 [==============================] - 6s 235ms/step - loss: 3.2809e-04
# Epoch 13/50
# 25/25 [==============================] - 4s 160ms/step - loss: 2.7949e-04
# Epoch 14/50
# 25/25 [==============================] - 4s 161ms/step - loss: 2.7807e-04
# Epoch 15/50
# 25/25 [==============================] - 6s 236ms/step - loss: 2.7743e-04
# Epoch 16/50
# 25/25 [==============================] - 4s 164ms/step - loss: 2.7664e-04
# Epoch 17/50
# 25/25 [==============================] - 4s 161ms/step - loss: 2.5634e-04
# Epoch 18/50
# 25/25 [==============================] - 6s 229ms/step - loss: 3.2089e-04
# Epoch 19/50
# 25/25 [==============================] - 4s 160ms/step - loss: 3.0379e-04
# Epoch 20/50
# 25/25 [==============================] - 4s 161ms/step - loss: 2.6417e-04
# Epoch 21/50
# 25/25 [==============================] - 6s 228ms/step - loss: 2.5993e-04
# Epoch 22/50
# 25/25 [==============================] - 4s 159ms/step - loss: 2.2823e-04
# Epoch 23/50
# 25/25 [==============================] - 4s 159ms/step - loss: 2.4606e-04
# Epoch 24/50
# 25/25 [==============================] - 6s 226ms/step - loss: 2.1208e-04
# Epoch 25/50
# 25/25 [==============================] - 4s 160ms/step - loss: 1.8832e-04
# Epoch 26/50
# 25/25 [==============================] - 4s 160ms/step - loss: 2.0034e-04
# Epoch 27/50
# 25/25 [==============================] - 6s 231ms/step - loss: 2.1464e-04
# Epoch 28/50
# 25/25 [==============================] - 4s 159ms/step - loss: 1.9667e-04
# Epoch 29/50
# 25/25 [==============================] - 4s 161ms/step - loss: 1.7947e-04
# Epoch 30/50
# 25/25 [==============================] - 6s 226ms/step - loss: 1.8890e-04
# Epoch 31/50
# 25/25 [==============================] - 4s 158ms/step - loss: 2.1578e-04
# Epoch 32/50
# 25/25 [==============================] - 4s 160ms/step - loss: 1.8832e-04
# Epoch 33/50
# 25/25 [==============================] - 5s 218ms/step - loss: 2.1460e-04
# Epoch 34/50
# 25/25 [==============================] - 4s 163ms/step - loss: 1.9324e-04

# %% [markdown]
# ### Dự đoán trên tập train

# %%
train_predictions = model_gasoline.predict(X_train)

# %%
train_predictions = scaler_price.inverse_transform(train_predictions)
y_train = scaler_price.inverse_transform(y_train.reshape(-1, 1))

# %%
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_mape = calculate_mape(y_train, train_predictions)

print(f'Training RMSE: {train_rmse:.2f}')
print(f'Training MAPE: {train_mape:.2f}%')

# %%
dates = df_coffee.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_train)], y=y_train.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(train_predictions)], y=train_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập huấn luyện (mô hình BiLSTM, dữ liệu giá cà phê và xăng)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()

# %% [markdown]
# ### Dự đoán trên tập test

# %%
test_predictions = model_gasoline.predict(X_test)

# %%
test_predictions = scaler_price.inverse_transform(test_predictions)
y_test = scaler_price.inverse_transform(y_test.reshape(-1, 1))

# %%
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
test_mape = calculate_mape(y_test, test_predictions)

print(f'Testing RMSE: {test_rmse:.2f}')
print(f'Testing MAPE: {test_mape:.2f}%')

# %%
dates = df_coffee.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_test)], y=y_test.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(test_predictions)], y=test_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập kiểm tra (mô hình BiLSTM, dữ liệu giá cà phê và xuất khẩu)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()

# %% [markdown]
# ### Đánh giá kết quả

# %%
results = pd.DataFrame({
    '': ['Train', 'Test'],
    'RMSE': [train_rmse, test_rmse],
    'MAPE (%)': [train_mape, test_mape]
})
results = results.round(2)

print(results)

# %% [markdown]
# ### Lưu mô hình

# %%
# from tensorflow.keras.models import load_model

# model_gasoline.save('LSTM_coffee_gasoline.h5')

# %% [markdown]
# ## Kết hợp giá cà phê, xuất khẩu, giá xăng

# %% [markdown]
# ### Xây dựng mô hình

# %%
start_date = df_gasoline.index.min()
df_coffee_filtered = df_coffee.loc[start_date:]

df_coffee_merged = pd.merge(df_coffee_filtered, df_coffee_export[['Trieu USD/ Nghin tan']], left_index=True, right_index=True, how='left')
df_coffee_merged['Trieu USD/ Nghin tan'] = df_coffee_merged['Trieu USD/ Nghin tan'].ffill()

df_coffee_merged = pd.merge(df_coffee_merged, df_gasoline[['RON 95-III']], left_index=True, right_index=True, how='left')
df_coffee_merged['RON 95-III'] = df_coffee_merged['RON 95-III'].ffill()

print(df_coffee_merged.tail())

# %%
# Preprocess data
scaler_price = MinMaxScaler(feature_range=(0, 1))
scaled_price = scaler_price.fit_transform(df_coffee_merged[['price']])

scaler_export = MinMaxScaler(feature_range=(0, 1))
scaled_export = scaler_export.fit_transform(df_coffee_merged[['Trieu USD/ Nghin tan']])

scaler_gasoline = MinMaxScaler(feature_range=(0, 1))
scaler_gasoline = scaler_gasoline.fit_transform(df_coffee_merged[['RON 95-III']])

scaled_data = np.concatenate((scaled_price, scaled_export), axis=1)
scaled_data = np.concatenate((scaled_data, scaler_gasoline), axis=1)

# %%
seq_length = 30
X, y = create_sequences(scaled_data, seq_length)

# %%
X.shape, y.shape

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print("Kích thước tập huấn luyện:", X_train.shape, y_train.shape)
print("Kích thước tập kiểm tra:", X_test.shape, y_test.shape)

# %%
model = Sequential()
model.add(Bidirectional(LSTM(units=128), input_shape=(seq_length, 3)))
model.add(Dropout(0.2))
model.add(Dense(units=64, activation='tanh'))
model.add(Dense(units=1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# %%
model.fit(X_train, y_train, epochs=50, batch_size=64, callbacks=[early_stopping])

# %% [markdown]
# ### Dự đoán trên tập train

# %%
train_predictions = model.predict(X_train)

# %%
train_predictions = scaler_price.inverse_transform(train_predictions)
y_train = scaler_price.inverse_transform(y_train.reshape(-1, 1))

# %%
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_mape = calculate_mape(y_train, train_predictions)

print(f'Training RMSE: {train_rmse:.2f}')
print(f'Training MAPE: {train_mape:.2f}%')

# %%
dates = df_coffee.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_train)], y=y_train.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(train_predictions)], y=train_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập huấn luyện (mô hình BiLSTM, dữ liệu giá cà phê, xuất khẩu, xăng)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()

# %% [markdown]
# ### Dự đoán trên tập test

# %%
test_predictions = model.predict(X_test)

# %%
test_predictions = scaler_price.inverse_transform(test_predictions)
y_test = scaler_price.inverse_transform(y_test.reshape(-1, 1))

# %%
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
test_mape = calculate_mape(y_test, test_predictions)

print(f'Testing RMSE: {test_rmse:.2f}')
print(f'Testing MAPE: {test_mape:.2f}%')

# %%
dates = df_coffee.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_test)], y=y_test.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(test_predictions)], y=test_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập kiểm tra (mô hình BiLSTM, dữ liệu giá cà phê, xuất khẩu, xăng)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()

# %% [markdown]
# ### Đánh giá kết quả

# %%
results = pd.DataFrame({
    '': ['Train', 'Test'],
    'RMSE': [train_rmse, test_rmse],
    'MAPE (%)': [train_mape, test_mape]
})
results = results.round(2)

print(results)
