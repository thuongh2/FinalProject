# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # DỮ LIỆU

# %% [markdown]
# ## GIÁ CÀ PHÊ

# %%
df_coffee = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/CaPhe/gia_cafe_den_2023.csv', encoding='ISO-8859-1')
df_coffee.tail()
# Out:
#             date    price
# 6203  12/27/2023  68000.0
# 6204  12/28/2023  68850.0
# 6205  12/29/2023  70000.0
# 6206  12/30/2023  68200.0
# 6207  12/31/2023  68200.0

# %%
df_coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6208 entries, 0 to 6207
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6208 non-null   object
#  1   price   6208 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 97.1+ KB

# %%
df_coffee['date'] = pd.to_datetime(df_coffee['date'])
df_coffee.set_index('date', inplace=True)

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_coffee, x=df_coffee.index, y='price')
plt.title('Biểu đồ giá cà phê tại Đăk Lăk')
plt.xlabel('Ngày')
plt.ylabel('Giá (đồng/kg)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_coffee = df_coffee.rolling(window=30, min_periods=1).mean()

# %% [markdown]
# # Mô hình dự đoán đơn biến

# %% [markdown]
# ## Xây dựng mô hình

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length)])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_price = scaler.fit_transform(df_coffee['price'].values.reshape(-1, 1))

# %%
seq_length = 30
X, y = create_sequences(scaled_price, seq_length)

# %%
X.shape, y.shape
# Out:
# ((6178, 30, 1), (6178, 1))

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print("Kích thước tập huấn luyện:", X_train.shape, y_train.shape)
print("Kích thước tập kiểm tra:", X_test.shape, y_test.shape)
# Out:
# Kích thước tập huấn luyện: (4942, 30, 1) (4942, 1)
# Kích thước tập kiểm tra: (1236, 30, 1) (1236, 1)

# %%
model = Sequential()
model.add(Bidirectional(LSTM(units=128, return_sequences=True), input_shape=(seq_length, 1)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(units=64), input_shape=(seq_length, 1)))
model.add(Dropout(0.2))
model.add(Dense(units=64, activation='tanh'))
model.add(Dense(units=1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# %%
model.fit(X_train, y_train, epochs=50, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 78/78 [==============================] - 26s 209ms/step - loss: 0.0059
# Epoch 2/50
# 78/78 [==============================] - 16s 210ms/step - loss: 6.9421e-04
# Epoch 3/50
# 78/78 [==============================] - 17s 216ms/step - loss: 5.3658e-04
# Epoch 4/50
# 78/78 [==============================] - 17s 219ms/step - loss: 3.9737e-04
# Epoch 5/50
# 78/78 [==============================] - 17s 222ms/step - loss: 3.1243e-04
# Epoch 6/50
# 78/78 [==============================] - 16s 209ms/step - loss: 2.3796e-04
# Epoch 7/50
# 78/78 [==============================] - 16s 208ms/step - loss: 2.5346e-04
# Epoch 8/50
# 78/78 [==============================] - 17s 224ms/step - loss: 2.1975e-04
# Epoch 9/50
# 78/78 [==============================] - 16s 210ms/step - loss: 1.7653e-04
# Epoch 10/50
# 78/78 [==============================] - 17s 219ms/step - loss: 1.7395e-04
# Epoch 11/50
# 78/78 [==============================] - 17s 219ms/step - loss: 1.5977e-04
# Epoch 12/50
# 78/78 [==============================] - 16s 209ms/step - loss: 1.3806e-04
# Epoch 13/50
# 78/78 [==============================] - 16s 208ms/step - loss: 1.4008e-04
# Epoch 14/50
# 78/78 [==============================] - 16s 211ms/step - loss: 1.1596e-04
# Epoch 15/50
# 78/78 [==============================] - 16s 207ms/step - loss: 1.1060e-04
# Epoch 16/50
# 78/78 [==============================] - 17s 218ms/step - loss: 1.1039e-04
# Epoch 17/50
# 78/78 [==============================] - 17s 216ms/step - loss: 1.1019e-04
# Epoch 18/50
# 78/78 [==============================] - 18s 231ms/step - loss: 1.0693e-04
# Epoch 19/50
# 78/78 [==============================] - 16s 206ms/step - loss: 1.1220e-04
# Epoch 20/50
# 78/78 [==============================] - 16s 209ms/step - loss: 9.4117e-05
# Epoch 21/50
# 78/78 [==============================] - 17s 217ms/step - loss: 1.0033e-04
# Epoch 22/50
# 78/78 [==============================] - 18s 224ms/step - loss: 9.3033e-05
# Epoch 23/50
# 78/78 [==============================] - 16s 211ms/step - loss: 8.5642e-05
# Epoch 24/50
# 78/78 [==============================] - 16s 206ms/step - loss: 9.4907e-05
# Epoch 25/50
# 78/78 [==============================] - 16s 209ms/step - loss: 1.0769e-04
# Epoch 26/50
# 78/78 [==============================] - 16s 207ms/step - loss: 9.6024e-05
# Epoch 27/50
# 78/78 [==============================] - 16s 210ms/step - loss: 7.7706e-05
# Epoch 28/50
# 78/78 [==============================] - 21s 265ms/step - loss: 8.0388e-05
# Epoch 29/50
# 78/78 [==============================] - 16s 210ms/step - loss: 8.6061e-05
# Epoch 30/50
# 78/78 [==============================] - 16s 211ms/step - loss: 8.4815e-05
# Epoch 31/50
# 78/78 [==============================] - 16s 209ms/step - loss: 8.8206e-05
# Epoch 32/50
# 78/78 [==============================] - 16s 209ms/step - loss: 8.8355e-05

# %% [markdown]
# ## Dự đoán tập train

# %%
train_predictions = model.predict(X_train)
# Out:
# 155/155 [==============================] - 12s 58ms/step

# %%
train_predictions = scaler.inverse_transform(train_predictions)
y_train = scaler.inverse_transform(y_train)

# %%
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_mape = calculate_mape(y_train, train_predictions)

print(f'Training RMSE: {train_rmse:.2f}')
print(f'Training MAPE: {train_mape:.2f}%')
# Out:
# Training RMSE: 189.13
# Training MAPE: 0.40%

# %%
dates = df_coffee.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_train)], y=y_train.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(train_predictions)], y=train_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập huấn luyện (mô hình BiLSTM)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5b21b5f8-5149-4c7e-a9ba-78944423a883" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b21b5f8-5149-4c7e-a9ba-78944423a883")) {                    Plotly.newPlot(                        "5b21b5f8-5149-4c7e-a9ba-78944423a883",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2007-01-02T00:00:00","2007-01-03T00:00:00","2007-01-04T00:00:00","2007-01-05T00:00:00","2007-01-06T00:00:00","2007-01-07T00:00:00","2007-01-08T00:00:00","2007-01-09T00:00:00","2007-01-10T00:00:00","2007-01-11T00:00:00","2007-01-12T00:00:00","2007-01-13T00:00:00","2007-01-14T00:00:00","2007-01-15T00:00:00","2007-01-16T00:00:00","2007-01-17T00:00:00","2007-01-18T00:00:00","2007-01-19T00:00:00","2007-01-20T00:00:00","2007-01-21T00:00:00","2007-01-22T00:00:00","2007-01-23T00:00:00","2007-01-24T00:00:00","2007-01-25T00:00:00","2007-01-26T00:00:00","2007-01-27T00:00:00","2007-01-28T00:00:00","2007-01-29T00:00:00","2007-01-30T00:00:00","2007-01-31T00:00:00","2007-02-01T00:00:00","2007-02-02T00:00:00","2007-02-03T00:00:00","2007-02-04T00:00:00","2007-02-05T00:00:00","2007-02-06T00:00:00","2007-02-07T00:00:00","2007-02-08T00:00:00","2007-02-09T00:00:00","2007-02-10T00:00:00","2007-02-11T00:00:00","2007-02-12T00:00:00","2007-02-13T00:00:00","2007-02-14T00:00:00","2007-02-15T00:00:00","2007-02-16T00:00:00","2007-02-17T00:00:00","2007-02-18T00:00:00","2007-02-19T00:00:00","2007-02-20T00:00:00","2007-02-21T00:00:00","2007-02-22T00:00:00","2007-02-23T00:00:00","2007-02-24T00:00:00","2007-02-25T00:00:00","2007-02-26T00:00:00","2007-02-27T00:00:00","2007-02-28T00:00:00","2007-03-01T00:00:00","2007-03-02T00:00:00","2007-03-03T00:00:00","2007-03-04T00:00:00","2007-03-05T00:00:00","2007-03-06T00:00:00","2007-03-07T00:00:00","2007-03-08T00:00:00","2007-03-09T00:00:00","2007-03-10T00:00:00","2007-03-11T00:00:00","2007-03-12T00:00:00","2007-03-13T00:00:00","2007-03-14T00:00:00","2007-03-15T00:00:00","2007-03-16T00:00:00","2007-03-17T00:00:00","2007-03-18T00:00:00","2007-03-19T00:00:00","2007-03-20T00:00:00","2007-03-21T00:00:00","2007-03-22T00:00:00","2007-03-23T00:00:00","2007-03-24T00:00:00","2007-03-25T00:00:00","2007-03-26T00:00:00","2007-03-27T00:00:00","2007-03-28T00:00:00","2007-03-29T00:00:00","2007-03-30T00:00:00","2007-03-31T00:00:00","2007-04-01T00:00:00","2007-04-02T00:00:00","2007-04-03T00:00:00","2007-04-04T00:00:00","2007-04-05T00:00:00","2007-04-06T00:00:00","2007-04-07T00:00:00","2007-04-08T00:00:00","2007-04-09T00:00:00","2007-04-10T00:00:00","2007-04-11T00:00:00","2007-04-12T00:00:00","2007-04-13T00:00:00","2007-04-14T00:00:00","2007-04-15T00:00:00","2007-04-16T00:00:00","2007-04-17T00:00:00","2007-04-18T00:00:00","2007-04-19T00:00:00","2007-04-20T00:00:00","2007-04-21T00:00:00","2007-04-22T00:00:00","2007-04-23T00:00:00","2007-04-24T00:00:00","2007-04-25T00:00:00","2007-04-26T00:00:00","2007-04-27T00:00:00","2007-04-28T00:00:00","2007-04-29T00:00:00","2007-04-30T00:00:00","2007-05-01T00:00:00","2007-05-02T00:00:00","2007-05-03T00:00:00","2007-05-04T00:00:00","2007-05-05T00:00:00","2007-05-06T00:00:00","2007-05-07T00:00:00","2007-05-08T00:00:00","2007-05-09T00:00:00","2007-05-10T00:00:00","2007-05-11T00:00:00","2007-05-12T00:00:00","2007-05-13T00:00:00","2007-05-14T00:00:00","2007-05-15T00:00:00","2007-05-16T00:00:00","2007-05-17T00:00:00","2007-05-18T00:00:00","2007-05-19T00:00:00","2007-05-20T00:00:00","2007-05-21T00:00:00","2007-05-22T00:00:00","2007-05-23T00:00:00","2007-05-24T00:00:00","2007-05-25T00:00:00","2007-05-26T00:00:00","2007-05-27T00:00:00","2007-05-28T00:00:00","2007-05-29T00:00:00","2007-05-30T00:00:00","2007-05-31T00:00:00","2007-06-01T00:00:00","2007-06-02T00:00:00","2007-06-03T00 ...

# %% [markdown]
# ## Dự đoán tập test

# %%
test_predictions = model.predict(X_test)
# Out:
# 39/39 [==============================] - 2s 42ms/step

# %%
test_predictions = scaler.inverse_transform(test_predictions)
y_test = scaler.inverse_transform(y_test)

# %%
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
test_mape = calculate_mape(y_test, test_predictions)

print(f'Testing RMSE: {test_rmse:.2f}')
print(f'Testing MAPE: {train_mape:.2f}%')
# Out:
# Testing RMSE: 411.60
# Testing MAPE: 0.40%

# %%
dates = df_coffee.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_test)], y=y_test.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(test_predictions)], y=test_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập kiểm tra (mô hình BiLSTM)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d8d85a7c-1186-4137-9fc5-c88c93127060" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8d85a7c-1186-4137-9fc5-c88c93127060")) {                    Plotly.newPlot(                        "d8d85a7c-1186-4137-9fc5-c88c93127060",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2007-01-02T00:00:00","2007-01-03T00:00:00","2007-01-04T00:00:00","2007-01-05T00:00:00","2007-01-06T00:00:00","2007-01-07T00:00:00","2007-01-08T00:00:00","2007-01-09T00:00:00","2007-01-10T00:00:00","2007-01-11T00:00:00","2007-01-12T00:00:00","2007-01-13T00:00:00","2007-01-14T00:00:00","2007-01-15T00:00:00","2007-01-16T00:00:00","2007-01-17T00:00:00","2007-01-18T00:00:00","2007-01-19T00:00:00","2007-01-20T00:00:00","2007-01-21T00:00:00","2007-01-22T00:00:00","2007-01-23T00:00:00","2007-01-24T00:00:00","2007-01-25T00:00:00","2007-01-26T00:00:00","2007-01-27T00:00:00","2007-01-28T00:00:00","2007-01-29T00:00:00","2007-01-30T00:00:00","2007-01-31T00:00:00","2007-02-01T00:00:00","2007-02-02T00:00:00","2007-02-03T00:00:00","2007-02-04T00:00:00","2007-02-05T00:00:00","2007-02-06T00:00:00","2007-02-07T00:00:00","2007-02-08T00:00:00","2007-02-09T00:00:00","2007-02-10T00:00:00","2007-02-11T00:00:00","2007-02-12T00:00:00","2007-02-13T00:00:00","2007-02-14T00:00:00","2007-02-15T00:00:00","2007-02-16T00:00:00","2007-02-17T00:00:00","2007-02-18T00:00:00","2007-02-19T00:00:00","2007-02-20T00:00:00","2007-02-21T00:00:00","2007-02-22T00:00:00","2007-02-23T00:00:00","2007-02-24T00:00:00","2007-02-25T00:00:00","2007-02-26T00:00:00","2007-02-27T00:00:00","2007-02-28T00:00:00","2007-03-01T00:00:00","2007-03-02T00:00:00","2007-03-03T00:00:00","2007-03-04T00:00:00","2007-03-05T00:00:00","2007-03-06T00:00:00","2007-03-07T00:00:00","2007-03-08T00:00:00","2007-03-09T00:00:00","2007-03-10T00:00:00","2007-03-11T00:00:00","2007-03-12T00:00:00","2007-03-13T00:00:00","2007-03-14T00:00:00","2007-03-15T00:00:00","2007-03-16T00:00:00","2007-03-17T00:00:00","2007-03-18T00:00:00","2007-03-19T00:00:00","2007-03-20T00:00:00","2007-03-21T00:00:00","2007-03-22T00:00:00","2007-03-23T00:00:00","2007-03-24T00:00:00","2007-03-25T00:00:00","2007-03-26T00:00:00","2007-03-27T00:00:00","2007-03-28T00:00:00","2007-03-29T00:00:00","2007-03-30T00:00:00","2007-03-31T00:00:00","2007-04-01T00:00:00","2007-04-02T00:00:00","2007-04-03T00:00:00","2007-04-04T00:00:00","2007-04-05T00:00:00","2007-04-06T00:00:00","2007-04-07T00:00:00","2007-04-08T00:00:00","2007-04-09T00:00:00","2007-04-10T00:00:00","2007-04-11T00:00:00","2007-04-12T00:00:00","2007-04-13T00:00:00","2007-04-14T00:00:00","2007-04-15T00:00:00","2007-04-16T00:00:00","2007-04-17T00:00:00","2007-04-18T00:00:00","2007-04-19T00:00:00","2007-04-20T00:00:00","2007-04-21T00:00:00","2007-04-22T00:00:00","2007-04-23T00:00:00","2007-04-24T00:00:00","2007-04-25T00:00:00","2007-04-26T00:00:00","2007-04-27T00:00:00","2007-04-28T00:00:00","2007-04-29T00:00:00","2007-04-30T00:00:00","2007-05-01T00:00:00","2007-05-02T00:00:00","2007-05-03T00:00:00","2007-05-04T00:00:00","2007-05-05T00:00:00","2007-05-06T00:00:00","2007-05-07T00:00:00","2007-05-08T00:00:00","2007-05-09T00:00:00","2007-05-10T00:00:00","2007-05-11T00:00:00","2007-05-12T00:00:00","2007-05-13T00:00:00","2007-05-14T00:00:00","2007-05-15T00:00:00","2007-05-16T00:00:00","2007-05-17T00:00:00","2007-05-18T00:00:00","2007-05-19T00:00:00","2007-05-20T00:00:00","2007-05-21T00:00:00","2007-05-22T00:00:00","2007-05-23T00:00:00","2007-05-24T00:00:00","2007-05-25T00:00:00","2007-05-26T00:00:00","2007-05-27T00:00:00","2007-05-28T00:00:00","2007-05-29T00:00:00","2007-05-30T00:00:00","2007-05-31T00:00:00","2007-06-01T00:00:00","2007-06-02T00:00:00","2007-06-03T00 ...

# %% [markdown]
# ## Đánh giá kết quả

# %%
results = pd.DataFrame({
    '': ['Train', 'Test'],
    'RMSE': [train_rmse, test_rmse],
    'MAPE (%)': [train_mape, test_mape]
})
results = results.round(2)

print(results)
# Out:
#             RMSE  MAPE (%)
# 0  Train  189.13      0.40
# 1   Test  411.60      0.47

# %% [markdown]
# ## Lưu mô hình

# %%
# from tensorflow.keras.models import load_model

# model.save('LSTM_coffee_daklak.h5')
