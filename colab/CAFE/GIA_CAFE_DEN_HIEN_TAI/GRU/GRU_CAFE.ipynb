# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Dữ liệu giá cà phê

# %%
df_coffee = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/CaPhe/gia_cafe.csv', encoding='ISO-8859-1')
df_coffee.tail()
# Out:
#            date     price
# 6353  5/28/2024  116700.0
# 6354  5/29/2024  120700.0
# 6355  5/30/2024  122700.0
# 6356  5/31/2024  123500.0
# 6357   6/1/2024  120000.0

# %%
df_coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6358 entries, 0 to 6357
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6358 non-null   object
#  1   price   6358 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 99.5+ KB

# %%
df_coffee['date'] = pd.to_datetime(df_coffee['date'])
df_coffee.set_index('date', inplace=True)

# %% [markdown]
# ### Điền dữ liệu ngày thiếu

# %%
idx = pd.date_range(df_coffee.index.min(), df_coffee.index.max())
df_coffee = df_coffee.reindex(idx)
df_coffee.fillna(method='ffill', inplace=True)
df_coffee.tail()

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_coffee, x=df_coffee.index, y='price')
plt.title('Biểu đồ giá cà phê tại Đăk Lăk')
plt.xlabel('Ngày')
plt.ylabel('Giá (đồng/kg)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Làm mịn dữ liệu

# %%
df_coffee = df_coffee.rolling(window=30, min_periods=1).mean()

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_coffee, x=df_coffee.index, y='price')
plt.title('Biểu đồ giá cà phê tại Đăk Lăk (đã được làm mịn)')
plt.xlabel('Ngày')
plt.ylabel('Giá (đồng/kg)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Mô hình dự đoán đơn biến

# %% [markdown]
# ## Xây dựng mô hình

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length)])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_price = scaler.fit_transform(df_coffee['price'].values.reshape(-1, 1))

# %%
seq_length = 30
X, y = create_sequences(scaled_price, seq_length)

# %%
X.shape, y.shape
# Out:
# ((6328, 30, 1), (6328, 1))

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print("Kích thước tập huấn luyện:", X_train.shape, y_train.shape)
print("Kích thước tập kiểm tra:", X_test.shape, y_test.shape)
# Out:
# Kích thước tập huấn luyện: (5062, 30, 1) (5062, 1)
# Kích thước tập kiểm tra: (1266, 30, 1) (1266, 1)

# %%
model = Sequential()
model.add(GRU(units=128, input_shape=(seq_length, 1)))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# %%
model.fit(X_train, y_train, epochs=50, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 80/80 [==============================] - 7s 60ms/step - loss: 0.0019
# Epoch 2/50
# 80/80 [==============================] - 4s 52ms/step - loss: 1.0616e-04
# Epoch 3/50
# 80/80 [==============================] - 3s 43ms/step - loss: 8.8066e-05
# Epoch 4/50
# 80/80 [==============================] - 4s 46ms/step - loss: 7.3380e-05
# Epoch 5/50
# 80/80 [==============================] - 5s 67ms/step - loss: 6.8417e-05
# Epoch 6/50
# 80/80 [==============================] - 3s 43ms/step - loss: 6.4110e-05
# Epoch 7/50
# 80/80 [==============================] - 3s 43ms/step - loss: 6.8225e-05
# Epoch 8/50
# 80/80 [==============================] - 5s 59ms/step - loss: 5.6665e-05
# Epoch 9/50
# 80/80 [==============================] - 4s 49ms/step - loss: 5.4937e-05
# Epoch 10/50
# 80/80 [==============================] - 4s 45ms/step - loss: 4.9930e-05
# Epoch 11/50
# 80/80 [==============================] - 3s 42ms/step - loss: 4.6301e-05
# Epoch 12/50
# 80/80 [==============================] - 5s 68ms/step - loss: 4.5874e-05
# Epoch 13/50
# 80/80 [==============================] - 3s 43ms/step - loss: 4.3854e-05
# Epoch 14/50
# 80/80 [==============================] - 3s 42ms/step - loss: 4.4862e-05
# Epoch 15/50
# 80/80 [==============================] - 5s 58ms/step - loss: 4.0767e-05
# Epoch 16/50
# 80/80 [==============================] - 5s 58ms/step - loss: 3.8104e-05
# Epoch 17/50
# 80/80 [==============================] - 3s 41ms/step - loss: 3.5887e-05
# Epoch 18/50
# 80/80 [==============================] - 3s 42ms/step - loss: 3.6615e-05
# Epoch 19/50
# 80/80 [==============================] - 5s 67ms/step - loss: 3.2629e-05
# Epoch 20/50
# 80/80 [==============================] - 4s 45ms/step - loss: 3.2796e-05
# Epoch 21/50
# 80/80 [==============================] - 4s 44ms/step - loss: 3.2587e-05
# Epoch 22/50
# 80/80 [==============================] - 4s 52ms/step - loss: 3.0373e-05
# Epoch 23/50
# 80/80 [==============================] - 5s 57ms/step - loss: 2.8947e-05
# Epoch 24/50
# 80/80 [==============================] - 3s 40ms/step - loss: 2.8379e-05
# Epoch 25/50
# 80/80 [==============================] - 4s 51ms/step - loss: 2.6502e-05
# Epoch 26/50
# 80/80 [==============================] - 5s 67ms/step - loss: 2.4671e-05
# Epoch 27/50
# 80/80 [==============================] - 4s 54ms/step - loss: 2.5787e-05
# Epoch 28/50
# 80/80 [==============================] - 4s 44ms/step - loss: 2.4597e-05
# Epoch 29/50
# 80/80 [==============================] - 5s 61ms/step - loss: 2.1979e-05
# Epoch 30/50
# 80/80 [==============================] - 4s 51ms/step - loss: 2.1045e-05
# Epoch 31/50
# 80/80 [==============================] - 4s 45ms/step - loss: 2.1824e-05
# Epoch 32/50
# 80/80 [==============================] - 4s 44ms/step - loss: 2.0091e-05
# Epoch 33/50
# 80/80 [==============================] - 5s 68ms/step - loss: 2.3431e-05
# Epoch 34/50
# 80/80 [==============================] - 4s 45ms/step - loss: 1.9292e-05
# Epoch 35/50
# 80/80 [==============================] - 3s 43ms/step - loss: 2.1065e-05
# Epoch 36/50
# 80/80 [==============================] - 5s 59ms/step - loss: 1.6242e-05
# Epoch 37/50
# 80/80 [==============================] - 4s 53ms/step - loss: 1.6106e-05
# Epoch 38/50
# 80/80 [==============================] - 3s 43ms/step - loss: 1.6900e-05
# Epoch 39/50
# 80/80 [==============================] - 4s 46ms/step - loss: 1.5830e-05
# Epoch 40/50
# 80/80 [==============================] - 5s 66ms/step - loss: 1.4646e-05
# Epoch 41/50
# 80/80 [==============================] - 4s 45ms/step - loss: 1.4416e-05
# Epoch 42/50
# 80/80 [==============================] - 3s 43ms/step - loss: 1.4708e-05
# Epoch 43/50
# 80/80 [==============================] - 5s 57ms/step - loss: 1.7495e-05
# Epoch 44/50
# 80/80 [==============================] - 4s 52ms/step - loss: 1.4798e-05
# Epoch 45/50
# 80/80 [==============================] - 5s 68ms/step - loss: 1.2268e-05
# Epoch 46/50
# 80/80 [==============================] - 8s 102ms/step - loss: 1.3317e-05
# Epoch 47/50
# 80/80 [==============================] - 8s 94ms/step - loss: 1.2918e-05
# Epoch 48/50
# 80/80 [==============================] - 7s 89ms/step - loss: 1.4229e-05
# Epoch 49/50
# 80/80 [==============================] - 3s 43ms/step - loss: 1.5112e-05
# Epoch 50/50
# 80/80 [==============================] - 4s 45ms/step - loss: 1.3987e-05

# %% [markdown]
# ## Dự đoán tập train

# %%
train_predictions = model.predict(X_train)
# Out:
# 159/159 [==============================] - 2s 9ms/step

# %%
train_predictions = scaler.inverse_transform(train_predictions)
y_train = scaler.inverse_transform(y_train)

# %%
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_mape = calculate_mape(y_train, train_predictions)

print(f'Training RMSE: {train_rmse:.2f}')
print(f'Training MAPE: {train_mape:.2f}%')
# Out:
# Training RMSE: 245.79
# Training MAPE: 0.67%

# %%
dates = df_coffee.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_train)], y=y_train.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(train_predictions)], y=train_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập huấn luyện (mô hình GRU)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="08d19b26-9991-4988-8a25-905e1860e390" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08d19b26-9991-4988-8a25-905e1860e390")) {                    Plotly.newPlot(                        "08d19b26-9991-4988-8a25-905e1860e390",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2007-01-02T00:00:00","2007-01-03T00:00:00","2007-01-04T00:00:00","2007-01-05T00:00:00","2007-01-06T00:00:00","2007-01-07T00:00:00","2007-01-08T00:00:00","2007-01-09T00:00:00","2007-01-10T00:00:00","2007-01-11T00:00:00","2007-01-12T00:00:00","2007-01-13T00:00:00","2007-01-14T00:00:00","2007-01-15T00:00:00","2007-01-16T00:00:00","2007-01-17T00:00:00","2007-01-18T00:00:00","2007-01-19T00:00:00","2007-01-20T00:00:00","2007-01-21T00:00:00","2007-01-22T00:00:00","2007-01-23T00:00:00","2007-01-24T00:00:00","2007-01-25T00:00:00","2007-01-26T00:00:00","2007-01-27T00:00:00","2007-01-28T00:00:00","2007-01-29T00:00:00","2007-01-30T00:00:00","2007-01-31T00:00:00","2007-02-01T00:00:00","2007-02-02T00:00:00","2007-02-03T00:00:00","2007-02-04T00:00:00","2007-02-05T00:00:00","2007-02-06T00:00:00","2007-02-07T00:00:00","2007-02-08T00:00:00","2007-02-09T00:00:00","2007-02-10T00:00:00","2007-02-11T00:00:00","2007-02-12T00:00:00","2007-02-13T00:00:00","2007-02-14T00:00:00","2007-02-15T00:00:00","2007-02-16T00:00:00","2007-02-17T00:00:00","2007-02-18T00:00:00","2007-02-19T00:00:00","2007-02-20T00:00:00","2007-02-21T00:00:00","2007-02-22T00:00:00","2007-02-23T00:00:00","2007-02-24T00:00:00","2007-02-25T00:00:00","2007-02-26T00:00:00","2007-02-27T00:00:00","2007-02-28T00:00:00","2007-03-01T00:00:00","2007-03-02T00:00:00","2007-03-03T00:00:00","2007-03-04T00:00:00","2007-03-05T00:00:00","2007-03-06T00:00:00","2007-03-07T00:00:00","2007-03-08T00:00:00","2007-03-09T00:00:00","2007-03-10T00:00:00","2007-03-11T00:00:00","2007-03-12T00:00:00","2007-03-13T00:00:00","2007-03-14T00:00:00","2007-03-15T00:00:00","2007-03-16T00:00:00","2007-03-17T00:00:00","2007-03-18T00:00:00","2007-03-19T00:00:00","2007-03-20T00:00:00","2007-03-21T00:00:00","2007-03-22T00:00:00","2007-03-23T00:00:00","2007-03-24T00:00:00","2007-03-25T00:00:00","2007-03-26T00:00:00","2007-03-27T00:00:00","2007-03-28T00:00:00","2007-03-29T00:00:00","2007-03-30T00:00:00","2007-03-31T00:00:00","2007-04-01T00:00:00","2007-04-02T00:00:00","2007-04-03T00:00:00","2007-04-04T00:00:00","2007-04-05T00:00:00","2007-04-06T00:00:00","2007-04-07T00:00:00","2007-04-08T00:00:00","2007-04-09T00:00:00","2007-04-10T00:00:00","2007-04-11T00:00:00","2007-04-12T00:00:00","2007-04-13T00:00:00","2007-04-14T00:00:00","2007-04-15T00:00:00","2007-04-16T00:00:00","2007-04-17T00:00:00","2007-04-18T00:00:00","2007-04-19T00:00:00","2007-04-20T00:00:00","2007-04-21T00:00:00","2007-04-22T00:00:00","2007-04-23T00:00:00","2007-04-24T00:00:00","2007-04-25T00:00:00","2007-04-26T00:00:00","2007-04-27T00:00:00","2007-04-28T00:00:00","2007-04-29T00:00:00","2007-04-30T00:00:00","2007-05-01T00:00:00","2007-05-02T00:00:00","2007-05-03T00:00:00","2007-05-04T00:00:00","2007-05-05T00:00:00","2007-05-06T00:00:00","2007-05-07T00:00:00","2007-05-08T00:00:00","2007-05-09T00:00:00","2007-05-10T00:00:00","2007-05-11T00:00:00","2007-05-12T00:00:00","2007-05-13T00:00:00","2007-05-14T00:00:00","2007-05-15T00:00:00","2007-05-16T00:00:00","2007-05-17T00:00:00","2007-05-18T00:00:00","2007-05-19T00:00:00","2007-05-20T00:00:00","2007-05-21T00:00:00","2007-05-22T00:00:00","2007-05-23T00:00:00","2007-05-24T00:00:00","2007-05-25T00:00:00","2007-05-26T00:00:00","2007-05-27T00:00:00","2007-05-28T00:00:00","2007-05-29T00:00:00","2007-05-30T00:00:00","2007-05-31T00:00:00","2007-06-01T00:00:00","2007-06-02T00:00:00","2007-06-03T00 ...

# %% [markdown]
# ## Dự đoán tập test

# %%
test_predictions = model.predict(X_test)
# Out:
# 40/40 [==============================] - 0s 11ms/step

# %%
test_predictions = scaler.inverse_transform(test_predictions)
y_test = scaler.inverse_transform(y_test)

# %%
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
test_mape = calculate_mape(y_test, test_predictions)

print(f'Testing RMSE: {test_rmse:.2f}')
print(f'Testing MAPE: {train_mape:.2f}%')
# Out:
# Testing RMSE: 331.12
# Testing MAPE: 0.67%

# %%
dates = df_coffee.index.tolist()
test_dates = dates[-len(y_test):]

fig = go.Figure()
fig.add_trace(go.Scatter(x=test_dates, y=y_test.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=test_dates, y=test_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập kiểm tra (mô hình GRU)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fcdc5f01-e9d2-4b48-8d1c-89bc5c478021" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcdc5f01-e9d2-4b48-8d1c-89bc5c478021")) {                    Plotly.newPlot(                        "fcdc5f01-e9d2-4b48-8d1c-89bc5c478021",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2007-01-02T00:00:00","2007-01-03T00:00:00","2007-01-04T00:00:00","2007-01-05T00:00:00","2007-01-06T00:00:00","2007-01-07T00:00:00","2007-01-08T00:00:00","2007-01-09T00:00:00","2007-01-10T00:00:00","2007-01-11T00:00:00","2007-01-12T00:00:00","2007-01-13T00:00:00","2007-01-14T00:00:00","2007-01-15T00:00:00","2007-01-16T00:00:00","2007-01-17T00:00:00","2007-01-18T00:00:00","2007-01-19T00:00:00","2007-01-20T00:00:00","2007-01-21T00:00:00","2007-01-22T00:00:00","2007-01-23T00:00:00","2007-01-24T00:00:00","2007-01-25T00:00:00","2007-01-26T00:00:00","2007-01-27T00:00:00","2007-01-28T00:00:00","2007-01-29T00:00:00","2007-01-30T00:00:00","2007-01-31T00:00:00","2007-02-01T00:00:00","2007-02-02T00:00:00","2007-02-03T00:00:00","2007-02-04T00:00:00","2007-02-05T00:00:00","2007-02-06T00:00:00","2007-02-07T00:00:00","2007-02-08T00:00:00","2007-02-09T00:00:00","2007-02-10T00:00:00","2007-02-11T00:00:00","2007-02-12T00:00:00","2007-02-13T00:00:00","2007-02-14T00:00:00","2007-02-15T00:00:00","2007-02-16T00:00:00","2007-02-17T00:00:00","2007-02-18T00:00:00","2007-02-19T00:00:00","2007-02-20T00:00:00","2007-02-21T00:00:00","2007-02-22T00:00:00","2007-02-23T00:00:00","2007-02-24T00:00:00","2007-02-25T00:00:00","2007-02-26T00:00:00","2007-02-27T00:00:00","2007-02-28T00:00:00","2007-03-01T00:00:00","2007-03-02T00:00:00","2007-03-03T00:00:00","2007-03-04T00:00:00","2007-03-05T00:00:00","2007-03-06T00:00:00","2007-03-07T00:00:00","2007-03-08T00:00:00","2007-03-09T00:00:00","2007-03-10T00:00:00","2007-03-11T00:00:00","2007-03-12T00:00:00","2007-03-13T00:00:00","2007-03-14T00:00:00","2007-03-15T00:00:00","2007-03-16T00:00:00","2007-03-17T00:00:00","2007-03-18T00:00:00","2007-03-19T00:00:00","2007-03-20T00:00:00","2007-03-21T00:00:00","2007-03-22T00:00:00","2007-03-23T00:00:00","2007-03-24T00:00:00","2007-03-25T00:00:00","2007-03-26T00:00:00","2007-03-27T00:00:00","2007-03-28T00:00:00","2007-03-29T00:00:00","2007-03-30T00:00:00","2007-03-31T00:00:00","2007-04-01T00:00:00","2007-04-02T00:00:00","2007-04-03T00:00:00","2007-04-04T00:00:00","2007-04-05T00:00:00","2007-04-06T00:00:00","2007-04-07T00:00:00","2007-04-08T00:00:00","2007-04-09T00:00:00","2007-04-10T00:00:00","2007-04-11T00:00:00","2007-04-12T00:00:00","2007-04-13T00:00:00","2007-04-14T00:00:00","2007-04-15T00:00:00","2007-04-16T00:00:00","2007-04-17T00:00:00","2007-04-18T00:00:00","2007-04-19T00:00:00","2007-04-20T00:00:00","2007-04-21T00:00:00","2007-04-22T00:00:00","2007-04-23T00:00:00","2007-04-24T00:00:00","2007-04-25T00:00:00","2007-04-26T00:00:00","2007-04-27T00:00:00","2007-04-28T00:00:00","2007-04-29T00:00:00","2007-04-30T00:00:00","2007-05-01T00:00:00","2007-05-02T00:00:00","2007-05-03T00:00:00","2007-05-04T00:00:00","2007-05-05T00:00:00","2007-05-06T00:00:00","2007-05-07T00:00:00","2007-05-08T00:00:00","2007-05-09T00:00:00","2007-05-10T00:00:00","2007-05-11T00:00:00","2007-05-12T00:00:00","2007-05-13T00:00:00","2007-05-14T00:00:00","2007-05-15T00:00:00","2007-05-16T00:00:00","2007-05-17T00:00:00","2007-05-18T00:00:00","2007-05-19T00:00:00","2007-05-20T00:00:00","2007-05-21T00:00:00","2007-05-22T00:00:00","2007-05-23T00:00:00","2007-05-24T00:00:00","2007-05-25T00:00:00","2007-05-26T00:00:00","2007-05-27T00:00:00","2007-05-28T00:00:00","2007-05-29T00:00:00","2007-05-30T00:00:00","2007-05-31T00:00:00","2007-06-01T00:00:00","2007-06-02T00:00:00","2007-06-03T00 ...

# %% [markdown]
# ## Đánh giá kết quả

# %%
results = pd.DataFrame({
    '': ['Train', 'Test'],
    'RMSE': [train_rmse, test_rmse],
    'MAPE (%)': [train_mape, test_mape]
})
results = results.round(2)

print(results)
# Out:
#             RMSE  MAPE (%)
# 0  Train  245.79      0.67
# 1   Test  331.12      0.60

# %% [markdown]
# ## Lưu mô hình

# %%
# model.save('GRU_gia_cafe.h5')
