# %% [markdown]
# # TRƯỜNG ĐẠI HỌC SƯ PHẠM KỸ THUẬT THÀNH PHỐ HỒ CHÍ MINH
# ## KHOA CÔNG NGHỆ THÔNG TIN
# ### BỘ MÔN KỸ THUẬT DỮ LIỆU
#
# # Đề tài:
# # ỨNG DỤNG PHƯƠNG PHÁP THỐNG KÊ VÀ HỌC MÁY ĐỂ DỰ ĐOÁN GIÁ NÔNG SẢN
#
# Sinh viên 1: Huỳnh Hạo Nhị - 20133006
#
# Sinh viên 2: Võ Hoài Thương - 20233012

# %% [markdown]
# # Thư viện

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Dữ liệu

# %% [markdown]
# ## Giá cà phê nội địa

# %% [markdown]
# Dữ liệu về giá cà phê được thu thập của tỉnh Đăk Lăk, từ website của Viện Chính sách và Chiến lược Phát triển Nông nghiệp Nông thôn từ năm 2007 đến nay.
# *   date*: ngày
# *   price: giá cà phê

# %%
df_coffee = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/CaPhe/gia_cafe.csv', encoding='ISO-8859-1')
df_coffee.tail()
# Out:
#            date     price
# 6353  5/28/2024  116700.0
# 6354  5/29/2024  120700.0
# 6355  5/30/2024  122700.0
# 6356  5/31/2024  123500.0
# 6357   6/1/2024  120000.0

# %%
df_coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6358 entries, 0 to 6357
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6358 non-null   object
#  1   price   6358 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 99.5+ KB

# %%
df_coffee['date'] = pd.to_datetime(df_coffee['date'])
df_coffee.set_index('date', inplace=True)

# %% [markdown]
# ### Điền dữ liệu ngày thiếu

# %%
idx = pd.date_range(df_coffee.index.min(), df_coffee.index.max())
df_coffee = df_coffee.reindex(idx)
df_coffee.fillna(method='ffill', inplace=True)
df_coffee.tail()
# Out:
#                price
# 2024-05-28  116700.0
# 2024-05-29  120700.0
# 2024-05-30  122700.0
# 2024-05-31  123500.0
# 2024-06-01  120000.0

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_coffee, x=df_coffee.index, y='price')
plt.title('Biểu đồ giá cà phê tại Đăk Lăk')
plt.xlabel('Ngày')
plt.ylabel('Giá (đồng/kg)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Giá xuất khẩu cà phê

# %% [markdown]
# Dữ liệu về giá trị xuất khẩu cà phê được thu thập từ website của Viện Chính sách và Chiến lược Phát triển Nông nghiệp Nông thôn.
# *   date*: ngày
# *   volume: Số lượng xuất khẩu (nghìn tấn)
# *   value: Kim ngạch xuất khẩu (triệu USD)
# *   value/volume: Giá trị xuất khẩu (triệu USD/nghìn tấn)

# %%
df_coffee_export = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/CaPhe/gia_xuat_khau_cafe.csv', encoding='ISO-8859-1')
df_coffee_export.head()
# Out:
#        date  volume   value  value/volume
# 0  1/1/2009  151.13  232.00      1.535102
# 1  2/1/2009  154.40  236.62      1.532513
# 2  3/1/2009  137.02  199.81      1.458254
# 3  4/1/2009  123.77  180.16      1.455603
# 4  5/1/2009   93.09  134.10      1.440541

# %%
df_coffee_export['date'] = pd.to_datetime(df_coffee_export['date'])
df_coffee_export.set_index('date', inplace=True)

# %% [markdown]
# ### Xử lý outlier

# %%
df_coffee_export[['value/volume']].boxplot()
# Out:
# <Axes: >

# %%
# Tính toán ngưỡng cho outlier sử dụng IQR
Q1 = df_coffee_export['value/volume'].quantile(0.25)
Q3 = df_coffee_export['value/volume'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Xác định các dòng dữ liệu có giá trị nằm ngoài ngưỡng
outliers = df_coffee_export[(df_coffee_export['value/volume'] < lower_bound) | (df_coffee_export['value/volume'] > upper_bound)]
print("Số lượng outlier:", len(outliers))
# Out:
# Số lượng outlier: 6

# %%
# Kiểm tra và thay đổi giá trị nếu nó nằm ngoài ngưỡng
df_coffee_export.at[df_coffee_export.index[0], 'value/volume'] = min(max(df_coffee_export.iloc[0]['value/volume'], lower_bound), upper_bound)

# Thay thế giá trị của outlier bằng giá trị trước đó
for index, row in outliers.iterrows():
    previous_date_index = df_coffee_export.index.get_loc(index) - 1
    if previous_date_index >= 0:
        previous_date = df_coffee_export.index[previous_date_index]
        previous_value = df_coffee_export.loc[previous_date, 'value/volume']
        df_coffee_export.at[index, 'value/volume'] = previous_value

# %%
df_coffee_export[['value/volume']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### Fill dữ liệu ngày bị thiếu

# %%
idx = pd.date_range(df_coffee_export.index.min(), df_coffee_export.index.max())
df_coffee_export = df_coffee_export.reindex(idx)

# %%
df_coffee_export.fillna(method='ffill', inplace=True)
df_coffee_export.head()
# Out:
#             volume  value  value/volume
# 2009-01-01  151.13  232.0      1.535102
# 2009-01-02  151.13  232.0      1.535102
# 2009-01-03  151.13  232.0      1.535102
# 2009-01-04  151.13  232.0      1.535102
# 2009-01-05  151.13  232.0      1.535102

# %% [markdown]
# ### Merge dữ liệu xuất khẩu vào giá cà phê

# %%
start_date = df_coffee_export.index.min()
df_coffee_filtered = df_coffee.loc[start_date:]

df_merged_coffee_export = pd.merge(df_coffee_filtered, df_coffee_export[['value/volume']], left_index=True, right_index=True, how='left')
df_merged_coffee_export['value/volume'] = df_merged_coffee_export['value/volume'].ffill()

print(df_merged_coffee_export.tail())
# Out:
#                price  value/volume
# 2024-05-28  116700.0      2.892161
# 2024-05-29  120700.0      2.892161
# 2024-05-30  122700.0      2.892161
# 2024-05-31  123500.0      2.892161
# 2024-06-01  120000.0      2.892161

# %% [markdown]
# ### Làm mịn dữ liệu

# %%
df_merged_coffee_export = df_merged_coffee_export.rolling(window=60, min_periods=1).mean()

# %% [markdown]
# ## Giá xăng

# %% [markdown]
# Dữ liệu giá xăng thu thập từ website của Công ty Dầu Việt Nam – CTCP.
# *   date*: ngày
# *   RON 95-III: giá xăng Ron 95-III

# %%
df_gasoline = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/Xang/gia_xang.csv', encoding='ISO-8859-1')
df_gasoline.tail()
# Out:
#            date  RON 95-III
# 170    2/5/2024       24.95
# 171    9/5/2024       23.54
# 172  16/05/2024       23.13
# 173  23/05/2024       23.21
# 174  29/05/2024       23.21

# %% [markdown]
# ### Xử lý outlier

# %%
df_gasoline[['RON 95-III']].boxplot()
# Out:
# <Axes: >

# %%
# Tính toán ngưỡng cho outlier sử dụng IQR
Q1 = df_gasoline['RON 95-III'].quantile(0.25)
Q3 = df_gasoline['RON 95-III'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Xác định các dòng dữ liệu có giá trị nằm ngoài ngưỡng
outliers = df_gasoline[(df_gasoline['RON 95-III'] < lower_bound) | (df_gasoline['RON 95-III'] > upper_bound)]
print("Số lượng outlier:", len(outliers))
# Out:
# Số lượng outlier: 14

# %%
# Kiểm tra và thay đổi giá trị nếu nó nằm ngoài ngưỡng
df_gasoline.at[df_gasoline.index[0], 'RON 95-III'] = min(max(df_gasoline.iloc[0]['RON 95-III'], lower_bound), upper_bound)

# Thay thế giá trị của outlier bằng giá trị trước đó
for index, row in outliers.iterrows():
    previous_date_index = df_gasoline.index.get_loc(index) - 1
    if previous_date_index >= 0:
        previous_date = df_gasoline.index[previous_date_index]
        previous_value = df_gasoline.loc[previous_date, 'RON 95-III']
        df_gasoline.at[index, 'RON 95-III'] = previous_value

# %%
df_gasoline[['RON 95-III']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### Fill dữ liệu ngày bị thiếu

# %%
df_gasoline['date'] = pd.to_datetime(df_gasoline['date'])
df_gasoline.set_index('date', inplace=True)
# Out:
# <ipython-input-24-2ca4586e2886>:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_gasoline['date'] = pd.to_datetime(df_gasoline['date'])

# %%
idx = pd.date_range(df_gasoline.index.min(), df_gasoline.index.max())
df_gasoline = df_gasoline.reindex(idx)
df_gasoline.fillna(method='ffill', inplace=True)

# %% [markdown]
# ### Merge dữ liệu xăng với cà phê

# %%
start_date = df_gasoline.index.min()
df_coffee_filtered = df_coffee.loc[start_date:]

df_merged_gasoline = pd.merge(df_coffee_filtered, df_gasoline[['RON 95-III']], left_index=True, right_index=True, how='left')
df_merged_gasoline['RON 95-III'] = df_merged_gasoline['RON 95-III'].ffill()

print(df_merged_gasoline.tail())
# Out:
#                price  RON 95-III
# 2024-05-28  116700.0       23.21
# 2024-05-29  120700.0       23.21
# 2024-05-30  122700.0       23.21
# 2024-05-31  123500.0       23.21
# 2024-06-01  120000.0       23.21

# %% [markdown]
# ### Làm mịn dữ liệu

# %%
df_merged_gasoline = df_merged_gasoline.rolling(window=30, min_periods=1).mean()

# %% [markdown]
# # Mô hình GRU dự đoán

# %% [markdown]
# Gated Recurrent Unit (GRU)  là mạng nơ-ron hồi quy có khả năng xử lý chuỗi thời gian dài hạn, là biến thể đơn giản hóa từ Long Short-Term Memory (LSTM) với cấu trúc gồm hai cổng:
# *   Cổng đặt lại (r): xác định phần thông tin của trạng thái ẩn trước cần loại bỏ bằng hàm sigmoid.
# *   Cổng cập nhật (z): xác định thông tin nào từ trạng thái ẩn trước được giữ lại và thông tin mới nào sẽ được thêm vào bằng hàm sigmoid.
# ![gru (1).png](data:image/png;base64,...)

# %% [markdown]
# ## Kết hợp giá cà phê, xuất khẩu, giá xăng

# %% [markdown]
# ### Xây dựng mô hình

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), :])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
start_date = df_gasoline.index.min()
df_coffee_filtered = df_coffee.loc[start_date:]

df_coffee_merged = pd.merge(df_coffee_filtered, df_coffee_export[['value/volume']], left_index=True, right_index=True, how='left')
df_coffee_merged['value/volume'] = df_coffee_merged['value/volume'].ffill()

df_coffee_merged = pd.merge(df_coffee_merged, df_gasoline[['RON 95-III']], left_index=True, right_index=True, how='left')
df_coffee_merged['RON 95-III'] = df_coffee_merged['RON 95-III'].ffill()

print(df_coffee_merged.tail())
# Out:
#                price  value/volume  RON 95-III
# 2024-05-28  116700.0      2.892161       23.21
# 2024-05-29  120700.0      2.892161       23.21
# 2024-05-30  122700.0      2.892161       23.21
# 2024-05-31  123500.0      2.892161       23.21
# 2024-06-01  120000.0      2.892161       23.21

# %%
correlation_matrix = df_coffee_merged.corr()

plt.figure(figsize=(6, 6), dpi=75)
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", linewidths=.5, cmap='coolwarm', center=0)
plt.title('Biểu đồ nhiệt ma trận tương quan')
plt.show()

# %%
df_coffee_merged = df_coffee_merged.rolling(window=30, min_periods=1).mean()

# %%
# Preprocess data
scaler_price = MinMaxScaler(feature_range=(0, 1))
scaled_price = scaler_price.fit_transform(df_coffee_merged[['price']])

scaler_export = MinMaxScaler(feature_range=(0, 1))
scaled_export = scaler_export.fit_transform(df_coffee_merged[['value/volume']])

scaler_gasoline = MinMaxScaler(feature_range=(0, 1))
scaler_gasoline = scaler_gasoline.fit_transform(df_coffee_merged[['RON 95-III']])

scaled_data = np.concatenate((scaled_price, scaled_export), axis=1)
scaled_data = np.concatenate((scaled_data, scaler_gasoline), axis=1)

# %%
seq_length = 30
X, y = create_sequences(scaled_data, seq_length)

# %%
X.shape, y.shape
# Out:
# ((2081, 30, 3), (2081,))

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print("Kích thước tập huấn luyện:", X_train.shape, y_train.shape)
print("Kích thước tập kiểm tra:", X_test.shape, y_test.shape)
# Out:
# Kích thước tập huấn luyện: (1664, 30, 3) (1664,)
# Kích thước tập kiểm tra: (417, 30, 3) (417,)

# %%
model = Sequential()
model.add(GRU(units=128, input_shape=(seq_length, 3)))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# %%
model.fit(X_train, y_train, epochs=50, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 26/26 [==============================] - 3s 45ms/step - loss: 0.0024
# Epoch 2/50
# 26/26 [==============================] - 1s 45ms/step - loss: 8.3983e-04
# Epoch 3/50
# 26/26 [==============================] - 1s 46ms/step - loss: 5.8400e-04
# Epoch 4/50
# 26/26 [==============================] - 2s 77ms/step - loss: 4.3462e-04
# Epoch 5/50
# 26/26 [==============================] - 2s 81ms/step - loss: 2.9315e-04
# Epoch 6/50
# 26/26 [==============================] - 1s 45ms/step - loss: 2.3184e-04
# Epoch 7/50
# 26/26 [==============================] - 1s 46ms/step - loss: 1.6615e-04
# Epoch 8/50
# 26/26 [==============================] - 1s 45ms/step - loss: 1.3635e-04
# Epoch 9/50
# 26/26 [==============================] - 1s 44ms/step - loss: 1.1780e-04
# Epoch 10/50
# 26/26 [==============================] - 1s 44ms/step - loss: 1.0037e-04
# Epoch 11/50
# 26/26 [==============================] - 1s 44ms/step - loss: 9.5393e-05
# Epoch 12/50
# 26/26 [==============================] - 1s 43ms/step - loss: 1.0729e-04
# Epoch 13/50
# 26/26 [==============================] - 1s 46ms/step - loss: 9.2761e-05
# Epoch 14/50
# 26/26 [==============================] - 2s 60ms/step - loss: 7.2955e-05
# Epoch 15/50
# 26/26 [==============================] - 2s 78ms/step - loss: 6.3131e-05
# Epoch 16/50
# 26/26 [==============================] - 2s 67ms/step - loss: 6.6174e-05
# Epoch 17/50
# 26/26 [==============================] - 1s 43ms/step - loss: 5.9621e-05
# Epoch 18/50
# 26/26 [==============================] - 1s 44ms/step - loss: 5.9653e-05
# Epoch 19/50
# 26/26 [==============================] - 1s 45ms/step - loss: 5.5322e-05
# Epoch 20/50
# 26/26 [==============================] - 1s 45ms/step - loss: 5.0647e-05
# Epoch 21/50
# 26/26 [==============================] - 1s 45ms/step - loss: 4.7873e-05
# Epoch 22/50
# 26/26 [==============================] - 1s 46ms/step - loss: 4.6943e-05
# Epoch 23/50
# 26/26 [==============================] - 1s 43ms/step - loss: 4.1071e-05
# Epoch 24/50
# 26/26 [==============================] - 1s 44ms/step - loss: 3.8071e-05
# Epoch 25/50
# 26/26 [==============================] - 2s 68ms/step - loss: 4.2483e-05
# Epoch 26/50
# 26/26 [==============================] - 2s 81ms/step - loss: 3.8919e-05
# Epoch 27/50
# 26/26 [==============================] - 1s 49ms/step - loss: 3.6856e-05
# Epoch 28/50
# 26/26 [==============================] - 1s 45ms/step - loss: 3.4012e-05
# Epoch 29/50
# 26/26 [==============================] - 1s 44ms/step - loss: 3.2022e-05
# Epoch 30/50
# 26/26 [==============================] - 1s 43ms/step - loss: 3.2157e-05
# Epoch 31/50
# 26/26 [==============================] - 1s 44ms/step - loss: 3.3350e-05
# Epoch 32/50
# 26/26 [==============================] - 1s 43ms/step - loss: 3.0147e-05
# Epoch 33/50
# 26/26 [==============================] - 1s 44ms/step - loss: 3.0297e-05
# Epoch 34/50
# 26/26 [==============================] - 1s 43ms/step - loss: 2.9438e-05
# Epoch 35/50
# 26/26 [==============================] - 1s 54ms/step - loss: 2.8773e-05
# Epoch 36/50
# 26/26 [==============================] - 2s 80ms/step - loss: 3.6023e-05
# Epoch 37/50
# 26/26 [==============================] - 2s 68ms/step - loss: 2.6847e-05
# Epoch 38/50
# 26/26 [==============================] - 1s 45ms/step - loss: 2.5764e-05
# Epoch 39/50
# 26/26 [==============================] - 1s 44ms/step - loss: 2.5259e-05
# Epoch 40/50
# 26/26 [==============================] - 1s 43ms/step - loss: 2.3835e-05
# Epoch 41/50
# 26/26 [==============================] - 1s 46ms/step - loss: 2.4196e-05
# Epoch 42/50
# 26/26 [==============================] - 1s 46ms/step - loss: 2.5139e-05
# Epoch 43/50
# 26/26 [==============================] - 1s 45ms/step - loss: 2.1373e-05
# Epoch 44/50
# 26/26 [==============================] - 1s 45ms/step - loss: 2.2136e-05
# Epoch 45/50
# 26/26 [==============================] - 1s 45ms/step - loss: 2.0911e-05
# Epoch 46/50
# 26/26 [==============================] - 2s 69ms/step - loss: 2.2168e-05
# Epoch 47/50
# 26/26 [==============================] - 2s 80ms/step - loss: 2.1484e-05
# Epoch 48/50
# 26/26 [==============================] - 2s 60ms/step - loss: 2.1804e-05
# Epoch 49/50
# 26/26 [==============================] - 1s 43ms/step - loss: 1.8985e-05
# Epoch 50/50
# 26/26 [==============================] - 1s 44ms/step - loss: 1.9451e-05

# %% [markdown]
# ### Dự đoán trên tập train

# %%
train_predictions = model.predict(X_train)
# Out:
# 52/52 [==============================] - 1s 9ms/step

# %%
train_predictions = scaler_price.inverse_transform(train_predictions)
y_train = scaler_price.inverse_transform(y_train.reshape(-1, 1))

# %%
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_mape = calculate_mape(y_train, train_predictions)

print(f'Training RMSE: {train_rmse:.2f}')
print(f'Training MAPE: {train_mape:.2f}%')
# Out:
# Training RMSE: 238.92
# Training MAPE: 0.47%

# %%
dates = df_coffee_merged.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_train)], y=y_train.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(train_predictions)], y=train_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập huấn luyện (mô hình GRU, dữ liệu giá cà phê, xuất khẩu, xăng)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aecee2ec-a0be-4b39-958f-999bcb02d76c" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aecee2ec-a0be-4b39-958f-999bcb02d76c")) {                    Plotly.newPlot(                        "aecee2ec-a0be-4b39-958f-999bcb02d76c",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2007-01-02T00:00:00","2007-01-03T00:00:00","2007-01-04T00:00:00","2007-01-05T00:00:00","2007-01-06T00:00:00","2007-01-07T00:00:00","2007-01-08T00:00:00","2007-01-09T00:00:00","2007-01-10T00:00:00","2007-01-11T00:00:00","2007-01-12T00:00:00","2007-01-13T00:00:00","2007-01-14T00:00:00","2007-01-15T00:00:00","2007-01-16T00:00:00","2007-01-17T00:00:00","2007-01-18T00:00:00","2007-01-19T00:00:00","2007-01-20T00:00:00","2007-01-21T00:00:00","2007-01-22T00:00:00","2007-01-23T00:00:00","2007-01-24T00:00:00","2007-01-25T00:00:00","2007-01-26T00:00:00","2007-01-27T00:00:00","2007-01-28T00:00:00","2007-01-29T00:00:00","2007-01-30T00:00:00","2007-01-31T00:00:00","2007-02-01T00:00:00","2007-02-02T00:00:00","2007-02-03T00:00:00","2007-02-04T00:00:00","2007-02-05T00:00:00","2007-02-06T00:00:00","2007-02-07T00:00:00","2007-02-08T00:00:00","2007-02-09T00:00:00","2007-02-10T00:00:00","2007-02-11T00:00:00","2007-02-12T00:00:00","2007-02-13T00:00:00","2007-02-14T00:00:00","2007-02-15T00:00:00","2007-02-16T00:00:00","2007-02-17T00:00:00","2007-02-18T00:00:00","2007-02-19T00:00:00","2007-02-20T00:00:00","2007-02-21T00:00:00","2007-02-22T00:00:00","2007-02-23T00:00:00","2007-02-24T00:00:00","2007-02-25T00:00:00","2007-02-26T00:00:00","2007-02-27T00:00:00","2007-02-28T00:00:00","2007-03-01T00:00:00","2007-03-02T00:00:00","2007-03-03T00:00:00","2007-03-04T00:00:00","2007-03-05T00:00:00","2007-03-06T00:00:00","2007-03-07T00:00:00","2007-03-08T00:00:00","2007-03-09T00:00:00","2007-03-10T00:00:00","2007-03-11T00:00:00","2007-03-12T00:00:00","2007-03-13T00:00:00","2007-03-14T00:00:00","2007-03-15T00:00:00","2007-03-16T00:00:00","2007-03-17T00:00:00","2007-03-18T00:00:00","2007-03-19T00:00:00","2007-03-20T00:00:00","2007-03-21T00:00:00","2007-03-22T00:00:00","2007-03-23T00:00:00","2007-03-24T00:00:00","2007-03-25T00:00:00","2007-03-26T00:00:00","2007-03-27T00:00:00","2007-03-28T00:00:00","2007-03-29T00:00:00","2007-03-30T00:00:00","2007-03-31T00:00:00","2007-04-01T00:00:00","2007-04-02T00:00:00","2007-04-03T00:00:00","2007-04-04T00:00:00","2007-04-05T00:00:00","2007-04-06T00:00:00","2007-04-07T00:00:00","2007-04-08T00:00:00","2007-04-09T00:00:00","2007-04-10T00:00:00","2007-04-11T00:00:00","2007-04-12T00:00:00","2007-04-13T00:00:00","2007-04-14T00:00:00","2007-04-15T00:00:00","2007-04-16T00:00:00","2007-04-17T00:00:00","2007-04-18T00:00:00","2007-04-19T00:00:00","2007-04-20T00:00:00","2007-04-21T00:00:00","2007-04-22T00:00:00","2007-04-23T00:00:00","2007-04-24T00:00:00","2007-04-25T00:00:00","2007-04-26T00:00:00","2007-04-27T00:00:00","2007-04-28T00:00:00","2007-04-29T00:00:00","2007-04-30T00:00:00","2007-05-01T00:00:00","2007-05-02T00:00:00","2007-05-03T00:00:00","2007-05-04T00:00:00","2007-05-05T00:00:00","2007-05-06T00:00:00","2007-05-07T00:00:00","2007-05-08T00:00:00","2007-05-09T00:00:00","2007-05-10T00:00:00","2007-05-11T00:00:00","2007-05-12T00:00:00","2007-05-13T00:00:00","2007-05-14T00:00:00","2007-05-15T00:00:00","2007-05-16T00:00:00","2007-05-17T00:00:00","2007-05-18T00:00:00","2007-05-19T00:00:00","2007-05-20T00:00:00","2007-05-21T00:00:00","2007-05-22T00:00:00","2007-05-23T00:00:00","2007-05-24T00:00:00","2007-05-25T00:00:00","2007-05-26T00:00:00","2007-05-27T00:00:00","2007-05-28T00:00:00","2007-05-29T00:00:00","2007-05-30T00:00:00","2007-05-31T00:00:00","2007-06-01T00:00:00","2007-06-02T00:00:00","2007-06-03T00 ...

# %% [markdown]
# ### Dự đoán trên tập test

# %%
test_predictions = model.predict(X_test)
# Out:
# 13/13 [==============================] - 0s 10ms/step

# %%
test_predictions = scaler_price.inverse_transform(test_predictions)
y_test = scaler_price.inverse_transform(y_test.reshape(-1, 1))

# %%
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
test_mape = calculate_mape(y_test, test_predictions)

print(f'Testing RMSE: {test_rmse:.2f}')
print(f'Testing MAPE: {test_mape:.2f}%')
# Out:
# Testing RMSE: 644.49
# Testing MAPE: 0.56%

# %%
dates = df_coffee_merged.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_train)], y=y_train.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(train_predictions)], y=train_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập huấn luyện (mô hình GRU, dữ liệu giá cà phê, xuất khẩu và giá xăng)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b8dcbed7-f486-4fbb-bafd-b02f01f65240" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8dcbed7-f486-4fbb-bafd-b02f01f65240")) {                    Plotly.newPlot(                        "b8dcbed7-f486-4fbb-bafd-b02f01f65240",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2007-01-02T00:00:00","2007-01-03T00:00:00","2007-01-04T00:00:00","2007-01-05T00:00:00","2007-01-06T00:00:00","2007-01-07T00:00:00","2007-01-08T00:00:00","2007-01-09T00:00:00","2007-01-10T00:00:00","2007-01-11T00:00:00","2007-01-12T00:00:00","2007-01-13T00:00:00","2007-01-14T00:00:00","2007-01-15T00:00:00","2007-01-16T00:00:00","2007-01-17T00:00:00","2007-01-18T00:00:00","2007-01-19T00:00:00","2007-01-20T00:00:00","2007-01-21T00:00:00","2007-01-22T00:00:00","2007-01-23T00:00:00","2007-01-24T00:00:00","2007-01-25T00:00:00","2007-01-26T00:00:00","2007-01-27T00:00:00","2007-01-28T00:00:00","2007-01-29T00:00:00","2007-01-30T00:00:00","2007-01-31T00:00:00","2007-02-01T00:00:00","2007-02-02T00:00:00","2007-02-03T00:00:00","2007-02-04T00:00:00","2007-02-05T00:00:00","2007-02-06T00:00:00","2007-02-07T00:00:00","2007-02-08T00:00:00","2007-02-09T00:00:00","2007-02-10T00:00:00","2007-02-11T00:00:00","2007-02-12T00:00:00","2007-02-13T00:00:00","2007-02-14T00:00:00","2007-02-15T00:00:00","2007-02-16T00:00:00","2007-02-17T00:00:00","2007-02-18T00:00:00","2007-02-19T00:00:00","2007-02-20T00:00:00","2007-02-21T00:00:00","2007-02-22T00:00:00","2007-02-23T00:00:00","2007-02-24T00:00:00","2007-02-25T00:00:00","2007-02-26T00:00:00","2007-02-27T00:00:00","2007-02-28T00:00:00","2007-03-01T00:00:00","2007-03-02T00:00:00","2007-03-03T00:00:00","2007-03-04T00:00:00","2007-03-05T00:00:00","2007-03-06T00:00:00","2007-03-07T00:00:00","2007-03-08T00:00:00","2007-03-09T00:00:00","2007-03-10T00:00:00","2007-03-11T00:00:00","2007-03-12T00:00:00","2007-03-13T00:00:00","2007-03-14T00:00:00","2007-03-15T00:00:00","2007-03-16T00:00:00","2007-03-17T00:00:00","2007-03-18T00:00:00","2007-03-19T00:00:00","2007-03-20T00:00:00","2007-03-21T00:00:00","2007-03-22T00:00:00","2007-03-23T00:00:00","2007-03-24T00:00:00","2007-03-25T00:00:00","2007-03-26T00:00:00","2007-03-27T00:00:00","2007-03-28T00:00:00","2007-03-29T00:00:00","2007-03-30T00:00:00","2007-03-31T00:00:00","2007-04-01T00:00:00","2007-04-02T00:00:00","2007-04-03T00:00:00","2007-04-04T00:00:00","2007-04-05T00:00:00","2007-04-06T00:00:00","2007-04-07T00:00:00","2007-04-08T00:00:00","2007-04-09T00:00:00","2007-04-10T00:00:00","2007-04-11T00:00:00","2007-04-12T00:00:00","2007-04-13T00:00:00","2007-04-14T00:00:00","2007-04-15T00:00:00","2007-04-16T00:00:00","2007-04-17T00:00:00","2007-04-18T00:00:00","2007-04-19T00:00:00","2007-04-20T00:00:00","2007-04-21T00:00:00","2007-04-22T00:00:00","2007-04-23T00:00:00","2007-04-24T00:00:00","2007-04-25T00:00:00","2007-04-26T00:00:00","2007-04-27T00:00:00","2007-04-28T00:00:00","2007-04-29T00:00:00","2007-04-30T00:00:00","2007-05-01T00:00:00","2007-05-02T00:00:00","2007-05-03T00:00:00","2007-05-04T00:00:00","2007-05-05T00:00:00","2007-05-06T00:00:00","2007-05-07T00:00:00","2007-05-08T00:00:00","2007-05-09T00:00:00","2007-05-10T00:00:00","2007-05-11T00:00:00","2007-05-12T00:00:00","2007-05-13T00:00:00","2007-05-14T00:00:00","2007-05-15T00:00:00","2007-05-16T00:00:00","2007-05-17T00:00:00","2007-05-18T00:00:00","2007-05-19T00:00:00","2007-05-20T00:00:00","2007-05-21T00:00:00","2007-05-22T00:00:00","2007-05-23T00:00:00","2007-05-24T00:00:00","2007-05-25T00:00:00","2007-05-26T00:00:00","2007-05-27T00:00:00","2007-05-28T00:00:00","2007-05-29T00:00:00","2007-05-30T00:00:00","2007-05-31T00:00:00","2007-06-01T00:00:00","2007-06-02T00:00:00","2007-06-03T00 ...

# %% [markdown]
# ### Đánh giá kết quả

# %%
results = pd.DataFrame({
    '': ['Train', 'Test'],
    'RMSE': [train_rmse, test_rmse],
    'MAPE (%)': [train_mape, test_mape]
})
results = results.round(2)

print(results)
# Out:
#             RMSE  MAPE (%)
# 0  Train  238.92      0.47
# 1   Test  644.49      0.56

# %% [markdown]
# ### Lưu mô hình

# %%
# model.save('GRU_gia_cafe_tong_hop.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
