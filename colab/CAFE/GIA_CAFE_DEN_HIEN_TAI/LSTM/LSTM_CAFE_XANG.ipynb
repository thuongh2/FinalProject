# %% [markdown]
# # TRƯỜNG ĐẠI HỌC SƯ PHẠM KỸ THUẬT THÀNH PHỐ HỒ CHÍ MINH
# ## KHOA CÔNG NGHỆ THÔNG TIN
# ### BỘ MÔN KỸ THUẬT DỮ LIỆU
#
# # Đề tài:
# # ỨNG DỤNG PHƯƠNG PHÁP THỐNG KÊ VÀ HỌC MÁY ĐỂ DỰ ĐOÁN GIÁ NÔNG SẢN
#
# Sinh viên 1: Huỳnh Hạo Nhị - 20133006
#
# Sinh viên 2: Võ Hoài Thương - 20233012

# %% [markdown]
# # Thư viện

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Dữ liệu

# %% [markdown]
# ## Giá cà phê nội địa

# %% [markdown]
# Dữ liệu về giá cà phê được thu thập của tỉnh Đăk Lăk, từ website của Viện Chính sách và Chiến lược Phát triển Nông nghiệp Nông thôn từ năm 2007 đến nay.
# *   date*: ngày
# *   price: giá cà phê

# %%
df_coffee = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/CaPhe/gia_cafe.csv', encoding='ISO-8859-1')
df_coffee.tail()
# Out:
#            date     price
# 6353  5/28/2024  116700.0
# 6354  5/29/2024  120700.0
# 6355  5/30/2024  122700.0
# 6356  5/31/2024  123500.0
# 6357   6/1/2024  120000.0

# %%
df_coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6358 entries, 0 to 6357
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6358 non-null   object
#  1   price   6358 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 99.5+ KB

# %%
df_coffee['date'] = pd.to_datetime(df_coffee['date'])
df_coffee.set_index('date', inplace=True)

# %% [markdown]
# ### Điền dữ liệu ngày thiếu

# %%
idx = pd.date_range(df_coffee.index.min(), df_coffee.index.max())
df_coffee = df_coffee.reindex(idx)
df_coffee.fillna(method='ffill', inplace=True)
df_coffee.tail()
# Out:
#                price
# 2024-05-28  116700.0
# 2024-05-29  120700.0
# 2024-05-30  122700.0
# 2024-05-31  123500.0
# 2024-06-01  120000.0

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_coffee, x=df_coffee.index, y='price')
plt.title('Biểu đồ giá cà phê tại Đăk Lăk')
plt.xlabel('Ngày')
plt.ylabel('Giá (đồng/kg)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Giá xăng

# %% [markdown]
# Dữ liệu giá xăng thu thập từ website của Công ty Dầu Việt Nam – CTCP.
# *   date*: ngày
# *   RON 95-III: giá xăng Ron 95-III

# %%
df_gasoline = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/Xang/gia_xang.csv', encoding='ISO-8859-1')
df_gasoline.tail()
# Out:
#            date  RON 95-III
# 170    2/5/2024       24.95
# 171    9/5/2024       23.54
# 172  16/05/2024       23.13
# 173  23/05/2024       23.21
# 174  29/05/2024       23.21

# %% [markdown]
# ### Xử lý outlier

# %%
df_gasoline[['RON 95-III']].boxplot()
# Out:
# <Axes: >

# %%
# boxplot = df_gasoline[['RON 95-III']].boxplot()
# boxplot.set_ylabel('Giá (đồng/lít)', fontsize=20)
# boxplot.tick_params(axis='x', labelsize=20)
# boxplot.tick_params(axis='y', labelsize=16)
# plt.show()

# %%
# Tính toán ngưỡng cho outlier sử dụng IQR
Q1 = df_gasoline['RON 95-III'].quantile(0.25)
Q3 = df_gasoline['RON 95-III'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Xác định các dòng dữ liệu có giá trị nằm ngoài ngưỡng
outliers = df_gasoline[(df_gasoline['RON 95-III'] < lower_bound) | (df_gasoline['RON 95-III'] > upper_bound)]
print("Số lượng outlier:", len(outliers))
# Out:
# Số lượng outlier: 14

# %%
# Kiểm tra và thay đổi giá trị nếu nó nằm ngoài ngưỡng
df_gasoline.at[df_gasoline.index[0], 'RON 95-III'] = min(max(df_gasoline.iloc[0]['RON 95-III'], lower_bound), upper_bound)

# Thay thế giá trị của outlier bằng giá trị trước đó
for index, row in outliers.iterrows():
    previous_date_index = df_gasoline.index.get_loc(index) - 1
    if previous_date_index >= 0:
        previous_date = df_gasoline.index[previous_date_index]
        previous_value = df_gasoline.loc[previous_date, 'RON 95-III']
        df_gasoline.at[index, 'RON 95-III'] = previous_value

# %%
df_gasoline[['RON 95-III']].boxplot()
# Out:
# <Axes: >

# %%
boxplot = df_gasoline[['RON 95-III']].boxplot()
boxplot.set_ylabel('Giá (đồng/lít)', fontsize=20)
boxplot.tick_params(axis='x', labelsize=20)
boxplot.tick_params(axis='y', labelsize=16)
plt.show()

# %% [markdown]
# ### Fill dữ liệu ngày bị thiếu

# %%
df_gasoline['date'] = pd.to_datetime(df_gasoline['date'])
df_gasoline.set_index('date', inplace=True)
# Out:
# <ipython-input-28-2ca4586e2886>:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_gasoline['date'] = pd.to_datetime(df_gasoline['date'])

# %%
idx = pd.date_range(df_gasoline.index.min(), df_gasoline.index.max())
df_gasoline = df_gasoline.reindex(idx)
df_gasoline.fillna(method='ffill', inplace=True)

# %% [markdown]
# ### Merge dữ liệu xăng với cà phê

# %%
start_date = df_gasoline.index.min()
df_coffee_filtered = df_coffee.loc[start_date:]

df_merged_gasoline = pd.merge(df_coffee_filtered, df_gasoline[['RON 95-III']], left_index=True, right_index=True, how='left')
df_merged_gasoline['RON 95-III'] = df_merged_gasoline['RON 95-III'].ffill()

print(df_merged_gasoline.tail())
# Out:
#                price  RON 95-III
# 2024-05-28  116700.0       23.21
# 2024-05-29  120700.0       23.21
# 2024-05-30  122700.0       23.21
# 2024-05-31  123500.0       23.21
# 2024-06-01  120000.0       23.21

# %%
correlation_matrix = df_merged_gasoline.corr()

plt.figure(figsize=(6, 6), dpi=75)
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", linewidths=.5, cmap='coolwarm', center=0)
plt.title('Biểu đồ nhiệt ma trận tương quan')
plt.show()

# %%
# correlation_matrix = df_merged_gasoline.corr()
# plt.figure(figsize=(6, 6), dpi=75)
# heatmap = sns.heatmap(correlation_matrix, annot=True, fmt=".2f", linewidths=.5, cmap='coolwarm', center=0, annot_kws={"size": 14})
# plt.title('Biểu đồ nhiệt ma trận tương quan', fontsize=18)
# plt.xticks(fontsize=14)
# plt.yticks(fontsize=14)
# cbar = heatmap.collections[0].colorbar
# cbar.ax.tick_params(labelsize=14)
# plt.show()

# %%
# df_merged_gasoline.to_csv('coffee_gasoline.csv', index=True)

# %% [markdown]
# ### Làm mịn dữ liệu

# %%
df_merged_gasoline = df_merged_gasoline.rolling(window=30, min_periods=1).mean()

# %% [markdown]
# # Mô hình LSTM dự đoán

# %% [markdown]
# Mạng LSTM (Long Short-Term Memory) là mạng nơ-ron hồi quy có khả năng xử lý chuỗi thời gian dài hạn với cấu trúc gồm ba cổng:
# *   Cổng quên (f): xác định thông tin nào của trạng thái tạm thời cũ được lưu trữ hoặc loại bỏ bằng hàm sigmoid.
# *   Cổng nhập (i): xác định thông tin được thêm vào trạng thái tạm thời bằng hàm sigmoid.
# *   Cổng xuất (o): xác định thông tin được xuất làm đầu ra của mạng LSTM hàm sigmoid.
# ![lstm (2).png](data:image/png;base64,...)

# %% [markdown]
# ## Giá cà phê kết hợp giá xăng

# %% [markdown]
# ### Xây dựng mô hình

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), :])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# Preprocess data
scaler_price = MinMaxScaler(feature_range=(0, 1))
scaled_price = scaler_price.fit_transform(df_merged_gasoline[['price']])

scaler_export = MinMaxScaler(feature_range=(0, 1))
scaled_export = scaler_export.fit_transform(df_merged_gasoline[['RON 95-III']])

scaled_data = np.concatenate((scaled_price, scaled_export), axis=1)

# %%
seq_length = 30
X, y = create_sequences(scaled_data, seq_length)

# %%
X.shape, y.shape
# Out:
# ((2078, 30, 2), (2078,))

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print("Kích thước tập huấn luyện:", X_train.shape, y_train.shape)
print("Kích thước tập kiểm tra:", X_test.shape, y_test.shape)
# Out:
# Kích thước tập huấn luyện: (1662, 30, 2) (1662,)
# Kích thước tập kiểm tra: (416, 30, 2) (416,)

# %%
model_gasoline = Sequential()
# model_gasoline.add(LSTM(units=128, return_sequences=True, input_shape=(seq_length, 2)))
model_gasoline.add(LSTM(units=128, input_shape=(seq_length, 2)))
model_gasoline.add(Dropout(0.2))
model_gasoline.add(Dense(units=1))

# %%
model_gasoline.compile(optimizer='adam', loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# %%
model_gasoline.fit(X_train, y_train, epochs=50, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 26/26 [==============================] - 8s 81ms/step - loss: 0.0028
# Epoch 2/50
# 26/26 [==============================] - 2s 97ms/step - loss: 8.9261e-04
# Epoch 3/50
# 26/26 [==============================] - 2s 79ms/step - loss: 2.8185e-04
# Epoch 4/50
# 26/26 [==============================] - 2s 83ms/step - loss: 2.0059e-04
# Epoch 5/50
# 26/26 [==============================] - 1s 49ms/step - loss: 1.5272e-04
# Epoch 6/50
# 26/26 [==============================] - 1s 45ms/step - loss: 1.4248e-04
# Epoch 7/50
# 26/26 [==============================] - 1s 46ms/step - loss: 1.2310e-04
# Epoch 8/50
# 26/26 [==============================] - 1s 45ms/step - loss: 1.0098e-04
# Epoch 9/50
# 26/26 [==============================] - 1s 43ms/step - loss: 1.1513e-04
# Epoch 10/50
# 26/26 [==============================] - 1s 47ms/step - loss: 8.1627e-05
# Epoch 11/50
# 26/26 [==============================] - 1s 45ms/step - loss: 8.4834e-05
# Epoch 12/50
# 26/26 [==============================] - 1s 47ms/step - loss: 6.4459e-05
# Epoch 13/50
# 26/26 [==============================] - 2s 66ms/step - loss: 5.7558e-05
# Epoch 14/50
# 26/26 [==============================] - 2s 87ms/step - loss: 5.6913e-05
# Epoch 15/50
# 26/26 [==============================] - 1s 52ms/step - loss: 5.6701e-05
# Epoch 16/50
# 26/26 [==============================] - 1s 45ms/step - loss: 4.7794e-05
# Epoch 17/50
# 26/26 [==============================] - 2s 73ms/step - loss: 4.8195e-05
# Epoch 18/50
# 26/26 [==============================] - 2s 95ms/step - loss: 4.8630e-05
# Epoch 19/50
# 26/26 [==============================] - 2s 92ms/step - loss: 4.1224e-05
# Epoch 20/50
# 26/26 [==============================] - 3s 107ms/step - loss: 3.9459e-05
# Epoch 21/50
# 26/26 [==============================] - 3s 118ms/step - loss: 4.0075e-05
# Epoch 22/50
# 26/26 [==============================] - 3s 100ms/step - loss: 4.5269e-05
# Epoch 23/50
# 26/26 [==============================] - 2s 95ms/step - loss: 4.6176e-05
# Epoch 24/50
# 26/26 [==============================] - 2s 90ms/step - loss: 4.1435e-05
# Epoch 25/50
# 26/26 [==============================] - 2s 90ms/step - loss: 4.1843e-05

# %% [markdown]
# ### Dự đoán trên tập train

# %%
train_predictions = model_gasoline.predict(X_train)
# Out:
# 52/52 [==============================] - 1s 13ms/step

# %%
train_predictions = scaler_price.inverse_transform(train_predictions)
y_train = scaler_price.inverse_transform(y_train.reshape(-1, 1))

# %%
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_mape = calculate_mape(y_train, train_predictions)

print(f'Training RMSE: {train_rmse:.2f}')
print(f'Training MAPE: {train_mape:.2f}%')
# Out:
# Training RMSE: 269.50
# Training MAPE: 0.55%

# %%
dates = df_merged_gasoline.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_train)], y=y_train.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(train_predictions)], y=train_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập huấn luyện (mô hình LSTM, dữ liệu giá cà phê và xăng)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="43e27d2a-1a99-42a0-9365-dd7b30ae438e" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43e27d2a-1a99-42a0-9365-dd7b30ae438e")) {                    Plotly.newPlot(                        "43e27d2a-1a99-42a0-9365-dd7b30ae438e",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2007-01-02T00:00:00","2007-01-03T00:00:00","2007-01-04T00:00:00","2007-01-05T00:00:00","2007-01-06T00:00:00","2007-01-07T00:00:00","2007-01-08T00:00:00","2007-01-09T00:00:00","2007-01-10T00:00:00","2007-01-11T00:00:00","2007-01-12T00:00:00","2007-01-13T00:00:00","2007-01-14T00:00:00","2007-01-15T00:00:00","2007-01-16T00:00:00","2007-01-17T00:00:00","2007-01-18T00:00:00","2007-01-19T00:00:00","2007-01-20T00:00:00","2007-01-21T00:00:00","2007-01-22T00:00:00","2007-01-23T00:00:00","2007-01-24T00:00:00","2007-01-25T00:00:00","2007-01-26T00:00:00","2007-01-27T00:00:00","2007-01-28T00:00:00","2007-01-29T00:00:00","2007-01-30T00:00:00","2007-01-31T00:00:00","2007-02-01T00:00:00","2007-02-02T00:00:00","2007-02-03T00:00:00","2007-02-04T00:00:00","2007-02-05T00:00:00","2007-02-06T00:00:00","2007-02-07T00:00:00","2007-02-08T00:00:00","2007-02-09T00:00:00","2007-02-10T00:00:00","2007-02-11T00:00:00","2007-02-12T00:00:00","2007-02-13T00:00:00","2007-02-14T00:00:00","2007-02-15T00:00:00","2007-02-16T00:00:00","2007-02-17T00:00:00","2007-02-18T00:00:00","2007-02-19T00:00:00","2007-02-20T00:00:00","2007-02-21T00:00:00","2007-02-22T00:00:00","2007-02-23T00:00:00","2007-02-24T00:00:00","2007-02-25T00:00:00","2007-02-26T00:00:00","2007-02-27T00:00:00","2007-02-28T00:00:00","2007-03-01T00:00:00","2007-03-02T00:00:00","2007-03-03T00:00:00","2007-03-04T00:00:00","2007-03-05T00:00:00","2007-03-06T00:00:00","2007-03-07T00:00:00","2007-03-08T00:00:00","2007-03-09T00:00:00","2007-03-10T00:00:00","2007-03-11T00:00:00","2007-03-12T00:00:00","2007-03-13T00:00:00","2007-03-14T00:00:00","2007-03-15T00:00:00","2007-03-16T00:00:00","2007-03-17T00:00:00","2007-03-18T00:00:00","2007-03-19T00:00:00","2007-03-20T00:00:00","2007-03-21T00:00:00","2007-03-22T00:00:00","2007-03-23T00:00:00","2007-03-24T00:00:00","2007-03-25T00:00:00","2007-03-26T00:00:00","2007-03-27T00:00:00","2007-03-28T00:00:00","2007-03-29T00:00:00","2007-03-30T00:00:00","2007-03-31T00:00:00","2007-04-01T00:00:00","2007-04-02T00:00:00","2007-04-03T00:00:00","2007-04-04T00:00:00","2007-04-05T00:00:00","2007-04-06T00:00:00","2007-04-07T00:00:00","2007-04-08T00:00:00","2007-04-09T00:00:00","2007-04-10T00:00:00","2007-04-11T00:00:00","2007-04-12T00:00:00","2007-04-13T00:00:00","2007-04-14T00:00:00","2007-04-15T00:00:00","2007-04-16T00:00:00","2007-04-17T00:00:00","2007-04-18T00:00:00","2007-04-19T00:00:00","2007-04-20T00:00:00","2007-04-21T00:00:00","2007-04-22T00:00:00","2007-04-23T00:00:00","2007-04-24T00:00:00","2007-04-25T00:00:00","2007-04-26T00:00:00","2007-04-27T00:00:00","2007-04-28T00:00:00","2007-04-29T00:00:00","2007-04-30T00:00:00","2007-05-01T00:00:00","2007-05-02T00:00:00","2007-05-03T00:00:00","2007-05-04T00:00:00","2007-05-05T00:00:00","2007-05-06T00:00:00","2007-05-07T00:00:00","2007-05-08T00:00:00","2007-05-09T00:00:00","2007-05-10T00:00:00","2007-05-11T00:00:00","2007-05-12T00:00:00","2007-05-13T00:00:00","2007-05-14T00:00:00","2007-05-15T00:00:00","2007-05-16T00:00:00","2007-05-17T00:00:00","2007-05-18T00:00:00","2007-05-19T00:00:00","2007-05-20T00:00:00","2007-05-21T00:00:00","2007-05-22T00:00:00","2007-05-23T00:00:00","2007-05-24T00:00:00","2007-05-25T00:00:00","2007-05-26T00:00:00","2007-05-27T00:00:00","2007-05-28T00:00:00","2007-05-29T00:00:00","2007-05-30T00:00:00","2007-05-31T00:00:00","2007-06-01T00:00:00","2007-06-02T00:00:00","2007-06-03T00 ...

# %% [markdown]
# ### Dự đoán trên tập test

# %%
test_predictions = model_gasoline.predict(X_test)
# Out:
# 13/13 [==============================] - 0s 13ms/step

# %%
test_predictions = scaler_price.inverse_transform(test_predictions)
y_test = scaler_price.inverse_transform(y_test.reshape(-1, 1))

# %%
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
test_mape = calculate_mape(y_test, test_predictions)

print(f'Testing RMSE: {test_rmse:.2f}')
print(f'Testing MAPE: {test_mape:.2f}%')
# Out:
# Testing RMSE: 2694.72
# Testing MAPE: 2.92%

# %%
dates = df_merged_gasoline.index.tolist()
test_dates = dates[-len(y_test):]

fig = go.Figure()
fig.add_trace(go.Scatter(x=test_dates, y=y_test.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=test_dates, y=test_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập kiểm tra (mô hình LSTM, dữ liệu giá cà phê và xăng)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="baf737fc-d45a-4201-a15b-9f6633ecb0a4" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("baf737fc-d45a-4201-a15b-9f6633ecb0a4")) {                    Plotly.newPlot(                        "baf737fc-d45a-4201-a15b-9f6633ecb0a4",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2007-01-02T00:00:00","2007-01-03T00:00:00","2007-01-04T00:00:00","2007-01-05T00:00:00","2007-01-06T00:00:00","2007-01-07T00:00:00","2007-01-08T00:00:00","2007-01-09T00:00:00","2007-01-10T00:00:00","2007-01-11T00:00:00","2007-01-12T00:00:00","2007-01-13T00:00:00","2007-01-14T00:00:00","2007-01-15T00:00:00","2007-01-16T00:00:00","2007-01-17T00:00:00","2007-01-18T00:00:00","2007-01-19T00:00:00","2007-01-20T00:00:00","2007-01-21T00:00:00","2007-01-22T00:00:00","2007-01-23T00:00:00","2007-01-24T00:00:00","2007-01-25T00:00:00","2007-01-26T00:00:00","2007-01-27T00:00:00","2007-01-28T00:00:00","2007-01-29T00:00:00","2007-01-30T00:00:00","2007-01-31T00:00:00","2007-02-01T00:00:00","2007-02-02T00:00:00","2007-02-03T00:00:00","2007-02-04T00:00:00","2007-02-05T00:00:00","2007-02-06T00:00:00","2007-02-07T00:00:00","2007-02-08T00:00:00","2007-02-09T00:00:00","2007-02-10T00:00:00","2007-02-11T00:00:00","2007-02-12T00:00:00","2007-02-13T00:00:00","2007-02-14T00:00:00","2007-02-15T00:00:00","2007-02-16T00:00:00","2007-02-17T00:00:00","2007-02-18T00:00:00","2007-02-19T00:00:00","2007-02-20T00:00:00","2007-02-21T00:00:00","2007-02-22T00:00:00","2007-02-23T00:00:00","2007-02-24T00:00:00","2007-02-25T00:00:00","2007-02-26T00:00:00","2007-02-27T00:00:00","2007-02-28T00:00:00","2007-03-01T00:00:00","2007-03-02T00:00:00","2007-03-03T00:00:00","2007-03-04T00:00:00","2007-03-05T00:00:00","2007-03-06T00:00:00","2007-03-07T00:00:00","2007-03-08T00:00:00","2007-03-09T00:00:00","2007-03-10T00:00:00","2007-03-11T00:00:00","2007-03-12T00:00:00","2007-03-13T00:00:00","2007-03-14T00:00:00","2007-03-15T00:00:00","2007-03-16T00:00:00","2007-03-17T00:00:00","2007-03-18T00:00:00","2007-03-19T00:00:00","2007-03-20T00:00:00","2007-03-21T00:00:00","2007-03-22T00:00:00","2007-03-23T00:00:00","2007-03-24T00:00:00","2007-03-25T00:00:00","2007-03-26T00:00:00","2007-03-27T00:00:00","2007-03-28T00:00:00","2007-03-29T00:00:00","2007-03-30T00:00:00","2007-03-31T00:00:00","2007-04-01T00:00:00","2007-04-02T00:00:00","2007-04-03T00:00:00","2007-04-04T00:00:00","2007-04-05T00:00:00","2007-04-06T00:00:00","2007-04-07T00:00:00","2007-04-08T00:00:00","2007-04-09T00:00:00","2007-04-10T00:00:00","2007-04-11T00:00:00","2007-04-12T00:00:00","2007-04-13T00:00:00","2007-04-14T00:00:00","2007-04-15T00:00:00","2007-04-16T00:00:00","2007-04-17T00:00:00","2007-04-18T00:00:00","2007-04-19T00:00:00","2007-04-20T00:00:00","2007-04-21T00:00:00","2007-04-22T00:00:00","2007-04-23T00:00:00","2007-04-24T00:00:00","2007-04-25T00:00:00","2007-04-26T00:00:00","2007-04-27T00:00:00","2007-04-28T00:00:00","2007-04-29T00:00:00","2007-04-30T00:00:00","2007-05-01T00:00:00","2007-05-02T00:00:00","2007-05-03T00:00:00","2007-05-04T00:00:00","2007-05-05T00:00:00","2007-05-06T00:00:00","2007-05-07T00:00:00","2007-05-08T00:00:00","2007-05-09T00:00:00","2007-05-10T00:00:00","2007-05-11T00:00:00","2007-05-12T00:00:00","2007-05-13T00:00:00","2007-05-14T00:00:00","2007-05-15T00:00:00","2007-05-16T00:00:00","2007-05-17T00:00:00","2007-05-18T00:00:00","2007-05-19T00:00:00","2007-05-20T00:00:00","2007-05-21T00:00:00","2007-05-22T00:00:00","2007-05-23T00:00:00","2007-05-24T00:00:00","2007-05-25T00:00:00","2007-05-26T00:00:00","2007-05-27T00:00:00","2007-05-28T00:00:00","2007-05-29T00:00:00","2007-05-30T00:00:00","2007-05-31T00:00:00","2007-06-01T00:00:00","2007-06-02T00:00:00","2007-06-03T00 ...

# %% [markdown]
# ### Đánh giá kết quả

# %%
results = pd.DataFrame({
    '': ['Train', 'Test'],
    'RMSE': [train_rmse, test_rmse],
    'MAPE (%)': [train_mape, test_mape]
})
results = results.round(2)

print(results)
# Out:
#              RMSE  MAPE (%)
# 0  Train   269.50      0.55
# 1   Test  2694.72      2.92

# %% [markdown]
# ### Lưu mô hình

# %%
# model_gasoline.save('LSTM_gia_cafe_xang.h5')
