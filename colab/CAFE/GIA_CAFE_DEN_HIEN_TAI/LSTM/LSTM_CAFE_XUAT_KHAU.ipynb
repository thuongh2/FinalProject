# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # DỮ LIỆU

# %% [markdown]
# ## GIÁ CÀ PHÊ

# %%
df_coffee = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/CaPhe/gia_cafe.csv', encoding='ISO-8859-1')
df_coffee.tail()
# Out:
#            date     price
# 6353  5/28/2024  116700.0
# 6354  5/29/2024  120700.0
# 6355  5/30/2024  122700.0
# 6356  5/31/2024  123500.0
# 6357   6/1/2024  120000.0

# %%
df_coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6358 entries, 0 to 6357
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6358 non-null   object
#  1   price   6358 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 99.5+ KB

# %%
df_coffee['date'] = pd.to_datetime(df_coffee['date'])
df_coffee.set_index('date', inplace=True)

# %% [markdown]
# ### Điền dữ liệu ngày thiếu

# %%
df_coffee.shape
# Out:
# (6358, 1)

# %%
idx = pd.date_range(df_coffee.index.min(), df_coffee.index.max())
df_coffee = df_coffee.reindex(idx)
df_coffee.fillna(method='ffill', inplace=True)
df_coffee.tail()
# Out:
#                price
# 2024-05-28  116700.0
# 2024-05-29  120700.0
# 2024-05-30  122700.0
# 2024-05-31  123500.0
# 2024-06-01  120000.0

# %%
df_coffee.shape
# Out:
# (6361, 1)

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_coffee, x=df_coffee.index, y='price')
plt.title('Biểu đồ giá cà phê tại Đăk Lăk')
plt.xlabel('Ngày')
plt.ylabel('Giá (đồng/kg)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## XUẤT KHẨU CÀ PHÊ

# %%
df_coffee_export = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/CaPhe/gia_xuat_khau_cafe.csv', encoding='ISO-8859-1')
df_coffee_export.head()
# Out:
#        date  Luong (nghin tan)  Kim ngach (trieu USD)  Trieu USD/ Nghin tan
# 0  1/1/2009             151.13                 232.00              1.535102
# 1  2/1/2009             154.40                 236.62              1.532513
# 2  3/1/2009             137.02                 199.81              1.458254
# 3  4/1/2009             123.77                 180.16              1.455603
# 4  5/1/2009              93.09                 134.10              1.440541

# %%
df_coffee_export['date'] = pd.to_datetime(df_coffee_export['date'])
df_coffee_export.set_index('date', inplace=True)

# %% [markdown]
# ### Xử lý outlier

# %%
df_coffee_export[['Trieu USD/ Nghin tan']].boxplot()
# Out:
# <Axes: >

# %%
# Tính toán ngưỡng cho outlier sử dụng IQR
Q1 = df_coffee_export['Trieu USD/ Nghin tan'].quantile(0.25)
Q3 = df_coffee_export['Trieu USD/ Nghin tan'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Xác định các dòng dữ liệu có giá trị nằm ngoài ngưỡng
outliers = df_coffee_export[(df_coffee_export['Trieu USD/ Nghin tan'] < lower_bound) | (df_coffee_export['Trieu USD/ Nghin tan'] > upper_bound)]
print("Số lượng outlier:", len(outliers))
# Out:
# Số lượng outlier: 6

# %%
# Kiểm tra và thay đổi giá trị nếu nó nằm ngoài ngưỡng
df_coffee_export.at[df_coffee_export.index[0], 'Trieu USD/ Nghin tan'] = min(max(df_coffee_export.iloc[0]['Trieu USD/ Nghin tan'], lower_bound), upper_bound)

# Thay thế giá trị của outlier bằng giá trị trước đó
for index, row in outliers.iterrows():
    previous_date_index = df_coffee_export.index.get_loc(index) - 1
    if previous_date_index >= 0:
        previous_date = df_coffee_export.index[previous_date_index]
        previous_value = df_coffee_export.loc[previous_date, 'Trieu USD/ Nghin tan']
        df_coffee_export.at[index, 'Trieu USD/ Nghin tan'] = previous_value

# %%
df_coffee_export[['Trieu USD/ Nghin tan']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### Fill dữ liệu ngày bị thiếu

# %%
idx = pd.date_range(df_coffee_export.index.min(), df_coffee_export.index.max())
df_coffee_export = df_coffee_export.reindex(idx)

# %%
df_coffee_export.fillna(method='ffill', inplace=True)
df_coffee_export.head()
# Out:
#             Luong (nghin tan)  Kim ngach (trieu USD)  Trieu USD/ Nghin tan
# 2009-01-01             151.13                  232.0              1.535102
# 2009-01-02             151.13                  232.0              1.535102
# 2009-01-03             151.13                  232.0              1.535102
# 2009-01-04             151.13                  232.0              1.535102
# 2009-01-05             151.13                  232.0              1.535102

# %% [markdown]
# ### Merge dữ liệu xuất khẩu vào giá cà phê

# %%
start_date = df_coffee_export.index.min()
df_coffee_filtered = df_coffee.loc[start_date:]

df_merged_coffee_export = pd.merge(df_coffee_filtered, df_coffee_export[['Trieu USD/ Nghin tan']], left_index=True, right_index=True, how='left')
df_merged_coffee_export['Trieu USD/ Nghin tan'] = df_merged_coffee_export['Trieu USD/ Nghin tan'].ffill()

print(df_merged_coffee_export.tail())
# Out:
#                price  Trieu USD/ Nghin tan
# 2024-05-28  116700.0              2.892161
# 2024-05-29  120700.0              2.892161
# 2024-05-30  122700.0              2.892161
# 2024-05-31  123500.0              2.892161
# 2024-06-01  120000.0              2.892161

# %%
correlation_matrix = df_merged_coffee_export.corr()

plt.figure(figsize=(6, 6), dpi=75)
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", linewidths=.5, cmap='coolwarm', center=0)
plt.title('Biểu đồ nhiệt ma trận tương quan')
plt.show()

# %%
# df_merged_coffee_export.to_csv('coffee_export.csv', index=True)

# %% [markdown]
# ### Làm mịn dữ liệu

# %%
df_merged_coffee_export = df_merged_coffee_export.rolling(window=60, min_periods=1).mean()

# %% [markdown]
# # Mô hình dự đoán

# %% [markdown]
# ## Giá cà phê kết hợp giá xuất khẩu

# %% [markdown]
# ### Xây dựng mô hình

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), :])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
df_coffee_export_predictions = df_merged_coffee_export.copy()

scaler_price = MinMaxScaler(feature_range=(0, 1))
scaled_price = scaler_price.fit_transform(df_coffee_export_predictions[['price']])

scaler_export = MinMaxScaler(feature_range=(0, 1))
scaled_export = scaler_export.fit_transform(df_coffee_export_predictions[['Trieu USD/ Nghin tan']])

scaled_data = np.concatenate((scaled_price, scaled_export), axis=1)

# %%
seq_length = 30
X, y = create_sequences(scaled_data, seq_length)

# %%
X.shape, y.shape
# Out:
# ((5598, 30, 2), (5598,))

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print("Kích thước tập huấn luyện:", X_train.shape, y_train.shape)
print("Kích thước tập kiểm tra:", X_test.shape, y_test.shape)
# Out:
# Kích thước tập huấn luyện: (4478, 30, 2) (4478,)
# Kích thước tập kiểm tra: (1120, 30, 2) (1120,)

# %%
model_coffee_export = Sequential()
# model_coffee_export.add(LSTM(units=128, return_sequences=True, input_shape=(seq_length, 2)))
model_coffee_export.add(LSTM(units=128, input_shape=(seq_length, 2)))
model_coffee_export.add(Dropout(0.2))
model_coffee_export.add(Dense(units=1))

# %%
model_coffee_export.compile(optimizer='adam', loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# %%
model_coffee_export.fit(X_train, y_train, epochs=50, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 70/70 [==============================] - 8s 61ms/step - loss: 0.0019
# Epoch 2/50
# 70/70 [==============================] - 4s 59ms/step - loss: 3.4958e-04
# Epoch 3/50
# 70/70 [==============================] - 6s 87ms/step - loss: 2.0131e-04
# Epoch 4/50
# 70/70 [==============================] - 4s 58ms/step - loss: 1.2966e-04
# Epoch 5/50
# 70/70 [==============================] - 4s 59ms/step - loss: 1.0416e-04
# Epoch 6/50
# 70/70 [==============================] - 6s 91ms/step - loss: 1.0464e-04
# Epoch 7/50
# 70/70 [==============================] - 4s 61ms/step - loss: 8.2221e-05
# Epoch 8/50
# 70/70 [==============================] - 4s 59ms/step - loss: 7.5008e-05
# Epoch 9/50
# 70/70 [==============================] - 6s 89ms/step - loss: 7.5986e-05
# Epoch 10/50
# 70/70 [==============================] - 4s 59ms/step - loss: 7.0613e-05
# Epoch 11/50
# 70/70 [==============================] - 4s 60ms/step - loss: 6.1330e-05
# Epoch 12/50
# 70/70 [==============================] - 6s 88ms/step - loss: 6.0238e-05
# Epoch 13/50
# 70/70 [==============================] - 4s 61ms/step - loss: 5.0970e-05
# Epoch 14/50
# 70/70 [==============================] - 4s 60ms/step - loss: 5.2945e-05
# Epoch 15/50
# 70/70 [==============================] - 6s 92ms/step - loss: 4.9250e-05
# Epoch 16/50
# 70/70 [==============================] - 6s 81ms/step - loss: 5.2378e-05
# Epoch 17/50
# 70/70 [==============================] - 6s 80ms/step - loss: 4.8340e-05
# Epoch 18/50
# 70/70 [==============================] - 5s 67ms/step - loss: 4.3405e-05
# Epoch 19/50
# 70/70 [==============================] - 4s 58ms/step - loss: 4.6761e-05
# Epoch 20/50
# 70/70 [==============================] - 6s 86ms/step - loss: 4.4377e-05
# Epoch 21/50
# 70/70 [==============================] - 5s 66ms/step - loss: 4.2235e-05
# Epoch 22/50
# 70/70 [==============================] - 4s 61ms/step - loss: 3.9173e-05
# Epoch 23/50
# 70/70 [==============================] - 6s 88ms/step - loss: 3.8515e-05
# Epoch 24/50
# 70/70 [==============================] - 5s 64ms/step - loss: 3.5945e-05
# Epoch 25/50
# 70/70 [==============================] - 4s 62ms/step - loss: 3.4863e-05
# Epoch 26/50
# 70/70 [==============================] - 6s 91ms/step - loss: 3.7931e-05
# Epoch 27/50
# 70/70 [==============================] - 4s 60ms/step - loss: 3.3517e-05
# Epoch 28/50
# 70/70 [==============================] - 4s 60ms/step - loss: 3.0796e-05
# Epoch 29/50
# 70/70 [==============================] - 6s 87ms/step - loss: 2.8777e-05
# Epoch 30/50
# 70/70 [==============================] - 4s 59ms/step - loss: 3.1722e-05
# Epoch 31/50
# 70/70 [==============================] - 4s 59ms/step - loss: 2.7818e-05
# Epoch 32/50
# 70/70 [==============================] - 6s 92ms/step - loss: 2.9044e-05
# Epoch 33/50
# 70/70 [==============================] - 4s 57ms/step - loss: 2.3736e-05
# Epoch 34/50
# 70/70 [==============================] - 4s 60ms/step - loss: 2.6469e-05
# Epoch 35/50
# 70/70 [==============================] - 6s 89ms/step - loss: 2.3630e-05
# Epoch 36/50
# 70/70 [==============================] - 4s 61ms/step - loss: 2.2968e-05
# Epoch 37/50
# 70/70 [==============================] - 4s 63ms/step - loss: 2.2520e-05
# Epoch 38/50
# 70/70 [==============================] - 7s 94ms/step - loss: 2.3023e-05
# Epoch 39/50
# 70/70 [==============================] - 4s 60ms/step - loss: 1.9632e-05
# Epoch 40/50
# 70/70 [==============================] - 4s 60ms/step - loss: 2.0924e-05
# Epoch 41/50
# 70/70 [==============================] - 6s 90ms/step - loss: 2.1651e-05
# Epoch 42/50
# 70/70 [==============================] - 4s 61ms/step - loss: 2.0648e-05
# Epoch 43/50
# 70/70 [==============================] - 4s 61ms/step - loss: 1.8895e-05
# Epoch 44/50
# 70/70 [==============================] - 6s 88ms/step - loss: 1.8391e-05
# Epoch 45/50
# 70/70 [==============================] - 4s 60ms/step - loss: 1.8282e-05
# Epoch 46/50
# 70/70 [==============================] - 4s 60ms/step - loss: 1.8436e-05
# Epoch 47/50
# 70/70 [==============================] - 6s 87ms/step - loss: 1.7708e-05
# Epoch 48/50
# 70/70 [==============================] - 4s 59ms/step - loss: 1.7706e-05
# Epoch 49/50
# 70/70 [==============================] - 4s 60ms/step - loss: 1.6422e-05
# Epoch 50/50
# 70/70 [==============================] - 6s 92ms/step - loss: 1.9784e-05

# %% [markdown]
# ### Dự đoán trên tập train

# %%
train_predictions = model_coffee_export.predict(X_train)
# Out:
# 140/140 [==============================] - 3s 17ms/step

# %%
train_predictions = scaler_price.inverse_transform(train_predictions)
y_train = scaler_price.inverse_transform(y_train.reshape(-1, 1))

# %%
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_mape = calculate_mape(y_train, train_predictions)

print(f'Training RMSE: {train_rmse:.2f}')
print(f'Training MAPE: {train_mape:.2f}%')
# Out:
# Training RMSE: 216.69
# Training MAPE: 0.51%

# %%
dates = df_merged_coffee_export.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_train)], y=y_train.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(train_predictions)], y=train_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập huấn luyện (mô hình LSTM, dữ liệu giá cà phê và xuất khẩu)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ff65a57e-f7fc-46a7-b195-08c025e358b6" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff65a57e-f7fc-46a7-b195-08c025e358b6")) {                    Plotly.newPlot(                        "ff65a57e-f7fc-46a7-b195-08c025e358b6",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2009-01-01T00:00:00","2009-01-02T00:00:00","2009-01-03T00:00:00","2009-01-04T00:00:00","2009-01-05T00:00:00","2009-01-06T00:00:00","2009-01-07T00:00:00","2009-01-08T00:00:00","2009-01-09T00:00:00","2009-01-10T00:00:00","2009-01-11T00:00:00","2009-01-12T00:00:00","2009-01-13T00:00:00","2009-01-14T00:00:00","2009-01-15T00:00:00","2009-01-16T00:00:00","2009-01-17T00:00:00","2009-01-18T00:00:00","2009-01-19T00:00:00","2009-01-20T00:00:00","2009-01-21T00:00:00","2009-01-22T00:00:00","2009-01-23T00:00:00","2009-01-24T00:00:00","2009-01-25T00:00:00","2009-01-26T00:00:00","2009-01-27T00:00:00","2009-01-28T00:00:00","2009-01-29T00:00:00","2009-01-30T00:00:00","2009-01-31T00:00:00","2009-02-01T00:00:00","2009-02-02T00:00:00","2009-02-03T00:00:00","2009-02-04T00:00:00","2009-02-05T00:00:00","2009-02-06T00:00:00","2009-02-07T00:00:00","2009-02-08T00:00:00","2009-02-09T00:00:00","2009-02-10T00:00:00","2009-02-11T00:00:00","2009-02-12T00:00:00","2009-02-13T00:00:00","2009-02-14T00:00:00","2009-02-15T00:00:00","2009-02-16T00:00:00","2009-02-17T00:00:00","2009-02-18T00:00:00","2009-02-19T00:00:00","2009-02-20T00:00:00","2009-02-21T00:00:00","2009-02-22T00:00:00","2009-02-23T00:00:00","2009-02-24T00:00:00","2009-02-25T00:00:00","2009-02-26T00:00:00","2009-02-27T00:00:00","2009-02-28T00:00:00","2009-03-01T00:00:00","2009-03-02T00:00:00","2009-03-03T00:00:00","2009-03-04T00:00:00","2009-03-05T00:00:00","2009-03-06T00:00:00","2009-03-07T00:00:00","2009-03-08T00:00:00","2009-03-09T00:00:00","2009-03-10T00:00:00","2009-03-11T00:00:00","2009-03-12T00:00:00","2009-03-13T00:00:00","2009-03-14T00:00:00","2009-03-15T00:00:00","2009-03-16T00:00:00","2009-03-17T00:00:00","2009-03-18T00:00:00","2009-03-19T00:00:00","2009-03-20T00:00:00","2009-03-21T00:00:00","2009-03-22T00:00:00","2009-03-23T00:00:00","2009-03-24T00:00:00","2009-03-25T00:00:00","2009-03-26T00:00:00","2009-03-27T00:00:00","2009-03-28T00:00:00","2009-03-29T00:00:00","2009-03-30T00:00:00","2009-03-31T00:00:00","2009-04-01T00:00:00","2009-04-02T00:00:00","2009-04-03T00:00:00","2009-04-04T00:00:00","2009-04-05T00:00:00","2009-04-06T00:00:00","2009-04-07T00:00:00","2009-04-08T00:00:00","2009-04-09T00:00:00","2009-04-10T00:00:00","2009-04-11T00:00:00","2009-04-12T00:00:00","2009-04-13T00:00:00","2009-04-14T00:00:00","2009-04-15T00:00:00","2009-04-16T00:00:00","2009-04-17T00:00:00","2009-04-18T00:00:00","2009-04-19T00:00:00","2009-04-20T00:00:00","2009-04-21T00:00:00","2009-04-22T00:00:00","2009-04-23T00:00:00","2009-04-24T00:00:00","2009-04-25T00:00:00","2009-04-26T00:00:00","2009-04-27T00:00:00","2009-04-28T00:00:00","2009-04-29T00:00:00","2009-04-30T00:00:00","2009-05-01T00:00:00","2009-05-02T00:00:00","2009-05-03T00:00:00","2009-05-04T00:00:00","2009-05-05T00:00:00","2009-05-06T00:00:00","2009-05-07T00:00:00","2009-05-08T00:00:00","2009-05-09T00:00:00","2009-05-10T00:00:00","2009-05-11T00:00:00","2009-05-12T00:00:00","2009-05-13T00:00:00","2009-05-14T00:00:00","2009-05-15T00:00:00","2009-05-16T00:00:00","2009-05-17T00:00:00","2009-05-18T00:00:00","2009-05-19T00:00:00","2009-05-20T00:00:00","2009-05-21T00:00:00","2009-05-22T00:00:00","2009-05-23T00:00:00","2009-05-24T00:00:00","2009-05-25T00:00:00","2009-05-26T00:00:00","2009-05-27T00:00:00","2009-05-28T00:00:00","2009-05-29T00:00:00","2009-05-30T00:00:00","2009-05-31T00:00:00","2009-06-01T00:00:00","2009-06-02T00 ...

# %%
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_mape = calculate_mape(y_train, train_predictions)

print(f'Training RMSE: {train_rmse:.2f}')
print(f'Training MAPE: {train_mape:.2f}%')
# Out:
# Training RMSE: 216.69
# Training MAPE: 0.51%

# %% [markdown]
# ### Dự đoán trên tập test

# %%
test_predictions = model_coffee_export.predict(X_test)
# Out:
# 35/35 [==============================] - 1s 18ms/step

# %%
test_predictions = scaler_price.inverse_transform(test_predictions)
y_test = scaler_price.inverse_transform(y_test.reshape(-1, 1))

# %%
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
test_mape = calculate_mape(y_test, test_predictions)

print(f'Testing RMSE: {test_rmse:.2f}')
print(f'Testing MAPE: {test_mape:.2f}%')
# Out:
# Testing RMSE: 683.19
# Testing MAPE: 0.85%

# %%
dates = df_merged_coffee_export.index.tolist()
test_dates = dates[-len(y_test):]

fig = go.Figure()
fig.add_trace(go.Scatter(x=test_dates, y=y_test.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=test_dates, y=test_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cà phê trên tập kiểm tra (mô hình LSTM, dữ liệu giá cà phê và xuất khẩu)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="74778bd0-0006-4393-9466-c52077d841af" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74778bd0-0006-4393-9466-c52077d841af")) {                    Plotly.newPlot(                        "74778bd0-0006-4393-9466-c52077d841af",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-08T00:00:00","2021-05-09T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-15T00:00:00","2021-05-16T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-22T00:00:00","2021-05-23T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-05-29T00:00:00","2021-05-30T00:00:00","2021-05-31T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-05T00:00:00","2021-06-06T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-12T00:00:00","2021-06-13T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-19T00:00:00","2021-06-20T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-26T00:00:00","2021-06-27T00:00:00","2021-06-28T00:00:00","2021-06-29T00:00:00","2021-06-30T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-03T00:00:00","2021-07-04T00:00:00","2021-07-05T00:00:00","2021-07-06T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-10T00:00:00","2021-07-11T00:00:00","2021-07-12T00:00:00","2021-07-13T00:00:00","2021-07-14T00:00:00","2021-07-15T00:00:00","2021-07-16T00:00:00","2021-07-17T00:00:00","2021-07-18T00:00:00","2021-07-19T00:00:00","2021-07-20T00:00:00","2021-07-21T00:00:00","2021-07-22T00:00:00","2021-07-23T00:00:00","2021-07-24T00:00:00","2021-07-25T00:00:00","2021-07-26T00:00:00","2021-07-27T00:00:00","2021-07-28T00:00:00","2021-07-29T00:00:00","2021-07-30T00:00:00","2021-07-31T00:00:00","2021-08-01T00:00:00","2021-08-02T00:00:00","2021-08-03T00:00:00","2021-08-04T00:00:00","2021-08-05T00:00:00","2021-08-06T00:00:00","2021-08-07T00:00:00","2021-08-08T00:00:00","2021-08-09T00:00:00","2021-08-10T00:00:00","2021-08-11T00:00:00","2021-08-12T00:00:00","2021-08-13T00:00:00","2021-08-14T00:00:00","2021-08-15T00:00:00","2021-08-16T00:00:00","2021-08-17T00:00:00","2021-08-18T00:00:00","2021-08-19T00:00:00","2021-08-20T00:00:00","2021-08-21T00:00:00","2021-08-22T00:00:00","2021-08-23T00:00:00","2021-08-24T00:00:00","2021-08-25T00:00:00","2021-08-26T00:00:00","2021-08-27T00:00:00","2021-08-28T00:00:00","2021-08-29T00:00:00","2021-08-30T00:00:00","2021-08-31T00:00:00","2021-09-01T00:00:00","2021-09-02T00:00:00","2021-09-03T00:00:00","2021-09-04T00:00:00","2021-09-05T00:00:00","2021-09-06T00:00:00","2021-09-07T00:00:00","2021-09-08T00:00:00","2021-09-09T00:00:00","2021-09-10T00:00:00","2021-09-11T00:00:00","2021-09-12T00:00:00","2021-09-13T00:00:00","2021-09-14T00:00:00","2021-09-15T00:00:00","2021-09-16T00:00:00","2021-09-17T00:00:00","2021-09-18T00:00:00","2021-09-19T00:00:00","2021-09-20T00:00:00","2021-09-21T00:00:00","2021-09-22T00:00:00","2021-09-23T00:00:00","2021-09-24T00:00:00","2021-09-25T00:00:00","2021-09-26T00:00:00","2021-09-27T00:00:00","2021-09-28T00:00:00","2021-09-29T00:00:00","2021-09-30T00:00:00","2021-10-01T00:00:00","2021-10-02T00:00:00","2021-10-03T00:00:00","2021-10-04T00:00:00","2021-10-05T00 ...

# %% [markdown]
# ### Đánh giá kết quả

# %%
results = pd.DataFrame({
    '': ['Train', 'Test'],
    'RMSE': [train_rmse, test_rmse],
    'MAPE (%)': [train_mape, test_mape]
})
results = results.round(2)

print(results)
# Out:
#             RMSE  MAPE (%)
# 0  Train  216.69      0.51
# 1   Test  683.19      0.85

# %% [markdown]
# ### Lưu mô hình

# %%
# model_coffee_export.save('LSTM_gia_cafe_xuat_khau.h5')
