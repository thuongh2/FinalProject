# %% [markdown]
# # TRƯỜNG ĐẠI HỌC SƯ PHẠM KỸ THUẬT THÀNH PHỐ HỒ CHÍ MINH
# ## KHOA CÔNG NGHỆ THÔNG TIN
# ### BỘ MÔN KỸ THUẬT DỮ LIỆU
#
# # Đề tài:
# # ỨNG DỤNG PHƯƠNG PHÁP THỐNG KÊ VÀ HỌC MÁY ĐỂ DỰ ĐOÁN GIÁ NÔNG SẢN
#
# Sinh viên 1: Huỳnh Hạo Nhị - 20133006
#
# Sinh viên 2: Võ Hoài Thương - 20233012

# %% [markdown]
# # Thư viện

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Dữ liệu

# %% [markdown]
# ## Giá cam nội địa

# %% [markdown]
# Dữ liệu giá cam được thu thập của tỉnh An Giang, từ website của Viện Chính sách và Chiến lược Phát triển Nông nghiệp Nông thôn từ năm 2007 đến nay.
# *   date*: ngày
# *   price: giá cam

# %%
df_orange = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/Cam/gia_cam.csv', encoding='ISO-8859-1')
df_orange.tail()
# Out:
#            date  price
# 6143  5/11/2024  30000
# 6144  5/12/2024  30000
# 6145  5/13/2024  30000
# 6146  5/14/2024  30000
# 6147  5/15/2024  30000

# %%
df_orange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6148 entries, 0 to 6147
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6148 non-null   object
#  1   price   6148 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 96.2+ KB

# %%
df_orange['date'] = pd.to_datetime(df_orange['date'])
df_orange.set_index('date', inplace=True)

# %% [markdown]
# ### Điền dữ liệu ngày thiếu

# %%
idx = pd.date_range(df_orange.index.min(), df_orange.index.max())
df_orange = df_orange.reindex(idx)
df_orange.fillna(method='ffill', inplace=True)
df_orange.tail()
# Out:
#             price
# 2024-05-11  30000
# 2024-05-12  30000
# 2024-05-13  30000
# 2024-05-14  30000
# 2024-05-15  30000

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_orange, x=df_orange.index, y='price')
plt.title('Biểu đồ giá cam tại An Giang')
plt.xlabel('Ngày')
plt.ylabel('Giá (đồng/kg)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Giá xăng

# %% [markdown]
# Dữ liệu giá xăng thu thập từ website của Công ty Dầu Việt Nam – CTCP.
# *   date*: ngày
# *   RON 95-III: giá xăng Ron 95-III

# %%
df_gasoline = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/Xang/gia_xang.csv', encoding='ISO-8859-1')
df_gasoline.tail()
# Out:
#            date  RON 95-III
# 170    2/5/2024       24.95
# 171    9/5/2024       23.54
# 172  16/05/2024       23.13
# 173  23/05/2024       23.21
# 174  29/05/2024       23.21

# %% [markdown]
# ### Xử lý outlier

# %%
df_gasoline[['RON 95-III']].boxplot()
# Out:
# <Axes: >

# %%
Q1 = df_gasoline['RON 95-III'].quantile(0.25)
Q3 = df_gasoline['RON 95-III'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
outliers = df_gasoline[(df_gasoline['RON 95-III'] < lower_bound) | (df_gasoline['RON 95-III'] > upper_bound)]
print("Số lượng outlier:", len(outliers))
# Out:
# Số lượng outlier: 14

# %%
df_gasoline.at[df_gasoline.index[0], 'RON 95-III'] = min(max(df_gasoline.iloc[0]['RON 95-III'], lower_bound), upper_bound)

for index, row in outliers.iterrows():
    previous_date_index = df_gasoline.index.get_loc(index) - 1
    if previous_date_index >= 0:
        previous_date = df_gasoline.index[previous_date_index]
        previous_value = df_gasoline.loc[previous_date, 'RON 95-III']
        df_gasoline.at[index, 'RON 95-III'] = previous_value

# %%
df_gasoline[['RON 95-III']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### Fill dữ liệu ngày bị thiếu

# %%
df_gasoline['date'] = pd.to_datetime(df_gasoline['date'])
df_gasoline.set_index('date', inplace=True)
# Out:
# <ipython-input-49-2ca4586e2886>:1: UserWarning:
#
# Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.

# %%
idx = pd.date_range(df_gasoline.index.min(), df_gasoline.index.max())
df_gasoline = df_gasoline.reindex(idx)
df_gasoline.fillna(method='ffill', inplace=True)

# %% [markdown]
# ### Merge dữ liệu xăng với cam

# %%
start_date = df_gasoline.index.min()
df_orange_filtered = df_orange.loc[start_date:]

df_merged_gasoline = pd.merge(df_orange_filtered, df_gasoline[['RON 95-III']], left_index=True, right_index=True, how='left')
df_merged_gasoline['RON 95-III'] = df_merged_gasoline['RON 95-III'].ffill()

print(df_merged_gasoline.tail())
# Out:
#             price  RON 95-III
# 2024-05-11  30000       23.54
# 2024-05-12  30000       23.54
# 2024-05-13  30000       23.54
# 2024-05-14  30000       23.54
# 2024-05-15  30000       23.54

# %%
correlation_matrix = df_merged_gasoline.corr()

plt.figure(figsize=(6, 6), dpi=75)
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", linewidths=.5, cmap='coolwarm', center=0)
plt.title('Biểu đồ nhiệt ma trận tương quan')
plt.show()

# %%
# df_merged_gasoline.to_csv('gia_cam_xang.csv', index=True)

# %% [markdown]
# ### Làm mịn dữ liệu

# %%
df_merged_gasoline = df_merged_gasoline.rolling(window=30, min_periods=1).mean()

# %% [markdown]
# # Mô hình LSTM dự đoán

# %% [markdown]
# Mạng LSTM (Long Short-Term Memory) là mạng nơ-ron hồi quy có khả năng xử lý chuỗi thời gian dài hạn với cấu trúc gồm ba cổng:
# *   Cổng quên (f): xác định thông tin nào của trạng thái tạm thời cũ được lưu trữ hoặc loại bỏ bằng hàm sigmoid.
# *   Cổng nhập (i): xác định thông tin được thêm vào trạng thái tạm thời bằng hàm sigmoid.
# *   Cổng xuất (o): xác định thông tin được xuất làm đầu ra của mạng LSTM hàm sigmoid.
# ![lstm (2).png](data:image/png;base64,...)

# %% [markdown]
# ## Giá cà phê kết hợp giá xăng

# %% [markdown]
# ### Xây dựng mô hình

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), :])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# Preprocess data
scaler_price = MinMaxScaler(feature_range=(0, 1))
scaled_price = scaler_price.fit_transform(df_merged_gasoline[['price']])

scaler_export = MinMaxScaler(feature_range=(0, 1))
scaled_export = scaler_export.fit_transform(df_merged_gasoline[['RON 95-III']])

scaled_data = np.concatenate((scaled_price, scaled_export), axis=1)

# %%
seq_length = 30
X, y = create_sequences(scaled_data, seq_length)

# %%
X.shape, y.shape
# Out:
# ((2064, 30, 2), (2064,))

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print("Kích thước tập huấn luyện:", X_train.shape, y_train.shape)
print("Kích thước tập kiểm tra:", X_test.shape, y_test.shape)
# Out:
# Kích thước tập huấn luyện: (1651, 30, 2) (1651,)
# Kích thước tập kiểm tra: (413, 30, 2) (413,)

# %%
model_gasoline = Sequential()
# model_gasoline.add(LSTM(units=128, return_sequences=True, input_shape=(seq_length, 2)))
model_gasoline.add(LSTM(units=128, input_shape=(seq_length, 2)))
model_gasoline.add(Dropout(0.2))
model_gasoline.add(Dense(units=1))

# %%
model_gasoline.compile(optimizer='adam', loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# %%
model_gasoline.fit(X_train, y_train, epochs=50, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 26/26 [==============================] - 3s 44ms/step - loss: 0.0384
# Epoch 2/50
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0038
# Epoch 3/50
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0025
# Epoch 4/50
# 26/26 [==============================] - 3s 97ms/step - loss: 0.0021
# Epoch 5/50
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0019
# Epoch 6/50
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0021
# Epoch 7/50
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0015
# Epoch 8/50
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0014
# Epoch 9/50
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0014
# Epoch 10/50
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0012
# Epoch 11/50
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0012
# Epoch 12/50
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0012
# Epoch 13/50
# 26/26 [==============================] - 2s 75ms/step - loss: 0.0011
# Epoch 14/50
# 26/26 [==============================] - 2s 72ms/step - loss: 9.5458e-04
# Epoch 15/50
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0010
# Epoch 16/50
# 26/26 [==============================] - 1s 43ms/step - loss: 9.6340e-04
# Epoch 17/50
# 26/26 [==============================] - 1s 43ms/step - loss: 8.8515e-04
# Epoch 18/50
# 26/26 [==============================] - 1s 43ms/step - loss: 9.2248e-04
# Epoch 19/50
# 26/26 [==============================] - 1s 43ms/step - loss: 9.0703e-04
# Epoch 20/50
# 26/26 [==============================] - 1s 43ms/step - loss: 8.7905e-04
# Epoch 21/50
# 26/26 [==============================] - 1s 43ms/step - loss: 8.8847e-04
# Epoch 22/50
# 26/26 [==============================] - 1s 44ms/step - loss: 8.6405e-04
# Epoch 23/50
# 26/26 [==============================] - 1s 51ms/step - loss: 8.2120e-04
# Epoch 24/50
# 26/26 [==============================] - 2s 78ms/step - loss: 9.5163e-04
# Epoch 25/50
# 26/26 [==============================] - 2s 65ms/step - loss: 7.9498e-04
# Epoch 26/50
# 26/26 [==============================] - 1s 43ms/step - loss: 8.0744e-04
# Epoch 27/50
# 26/26 [==============================] - 1s 43ms/step - loss: 7.1278e-04
# Epoch 28/50
# 26/26 [==============================] - 1s 43ms/step - loss: 8.9666e-04
# Epoch 29/50
# 26/26 [==============================] - 1s 41ms/step - loss: 8.8463e-04
# Epoch 30/50
# 26/26 [==============================] - 1s 42ms/step - loss: 7.7527e-04
# Epoch 31/50
# 26/26 [==============================] - 1s 41ms/step - loss: 7.1418e-04
# Epoch 32/50
# 26/26 [==============================] - 1s 44ms/step - loss: 8.0854e-04

# %% [markdown]
# ### Dự đoán trên tập train

# %%
train_predictions = model_gasoline.predict(X_train)
# Out:
# 52/52 [==============================] - 1s 11ms/step

# %%
train_predictions = scaler_price.inverse_transform(train_predictions)
y_train = scaler_price.inverse_transform(y_train.reshape(-1, 1))

# %%
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_mape = calculate_mape(y_train, train_predictions)

print(f'Training RMSE: {train_rmse:.2f}')
print(f'Training MAPE: {train_mape:.2f}%')
# Out:
# Training RMSE: 431.05
# Training MAPE: 1.02%

# %%
dates = df_merged_gasoline.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_train)], y=y_train.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(train_predictions)], y=train_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá cam trên tập huấn luyện (mô hình LSTM, dữ liệu giá cam và giá xăng)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="829d410c-6f69-4d64-97ea-cf715b247a20" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("829d410c-6f69-4d64-97ea-cf715b247a20")) {                    Plotly.newPlot(                        "829d410c-6f69-4d64-97ea-cf715b247a20",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2018-08-22T00:00:00","2018-08-23T00:00:00","2018-08-24T00:00:00","2018-08-25T00:00:00","2018-08-26T00:00:00","2018-08-27T00:00:00","2018-08-28T00:00:00","2018-08-29T00:00:00","2018-08-30T00:00:00","2018-08-31T00:00:00","2018-09-01T00:00:00","2018-09-02T00:00:00","2018-09-03T00:00:00","2018-09-04T00:00:00","2018-09-05T00:00:00","2018-09-06T00:00:00","2018-09-07T00:00:00","2018-09-08T00:00:00","2018-09-09T00:00:00","2018-09-10T00:00:00","2018-09-11T00:00:00","2018-09-12T00:00:00","2018-09-13T00:00:00","2018-09-14T00:00:00","2018-09-15T00:00:00","2018-09-16T00:00:00","2018-09-17T00:00:00","2018-09-18T00:00:00","2018-09-19T00:00:00","2018-09-20T00:00:00","2018-09-21T00:00:00","2018-09-22T00:00:00","2018-09-23T00:00:00","2018-09-24T00:00:00","2018-09-25T00:00:00","2018-09-26T00:00:00","2018-09-27T00:00:00","2018-09-28T00:00:00","2018-09-29T00:00:00","2018-09-30T00:00:00","2018-10-01T00:00:00","2018-10-02T00:00:00","2018-10-03T00:00:00","2018-10-04T00:00:00","2018-10-05T00:00:00","2018-10-06T00:00:00","2018-10-07T00:00:00","2018-10-08T00:00:00","2018-10-09T00:00:00","2018-10-10T00:00:00","2018-10-11T00:00:00","2018-10-12T00:00:00","2018-10-13T00:00:00","2018-10-14T00:00:00","2018-10-15T00:00:00","2018-10-16T00:00:00","2018-10-17T00:00:00","2018-10-18T00:00:00","2018-10-19T00:00:00","2018-10-20T00:00:00","2018-10-21T00:00:00","2018-10-22T00:00:00","2018-10-23T00:00:00","2018-10-24T00:00:00","2018-10-25T00:00:00","2018-10-26T00:00:00","2018-10-27T00:00:00","2018-10-28T00:00:00","2018-10-29T00:00:00","2018-10-30T00:00:00","2018-10-31T00:00:00","2018-11-01T00:00:00","2018-11-02T00:00:00","2018-11-03T00:00:00","2018-11-04T00:00:00","2018-11-05T00:00:00","2018-11-06T00:00:00","2018-11-07T00:00:00","2018-11-08T00:00:00","2018-11-09T00:00:00","2018-11-10T00:00:00","2018-11-11T00:00:00","2018-11-12T00:00:00","2018-11-13T00:00:00","2018-11-14T00:00:00","2018-11-15T00:00:00","2018-11-16T00:00:00","2018-11-17T00:00:00","2018-11-18T00:00:00","2018-11-19T00:00:00","2018-11-20T00:00:00","2018-11-21T00:00:00","2018-11-22T00:00:00","2018-11-23T00:00:00","2018-11-24T00:00:00","2018-11-25T00:00:00","2018-11-26T00:00:00","2018-11-27T00:00:00","2018-11-28T00:00:00","2018-11-29T00:00:00","2018-11-30T00:00:00","2018-12-01T00:00:00","2018-12-02T00:00:00","2018-12-03T00:00:00","2018-12-04T00:00:00","2018-12-05T00:00:00","2018-12-06T00:00:00","2018-12-07T00:00:00","2018-12-08T00:00:00","2018-12-09T00:00:00","2018-12-10T00:00:00","2018-12-11T00:00:00","2018-12-12T00:00:00","2018-12-13T00:00:00","2018-12-14T00:00:00","2018-12-15T00:00:00","2018-12-16T00:00:00","2018-12-17T00:00:00","2018-12-18T00:00:00","2018-12-19T00:00:00","2018-12-20T00:00:00","2018-12-21T00:00:00","2018-12-22T00:00:00","2018-12-23T00:00:00","2018-12-24T00:00:00","2018-12-25T00:00:00","2018-12-26T00:00:00","2018-12-27T00:00:00","2018-12-28T00:00:00","2018-12-29T00:00:00","2018-12-30T00:00:00","2018-12-31T00:00:00","2019-01-01T00:00:00","2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-05T00:00:00","2019-01-06T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-12T00:00:00","2019-01-13T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-19T00:00:00","2019-01-20T00:00:00","2019-01-21T00 ...

# %% [markdown]
# ### Dự đoán trên tập test

# %%
test_predictions = model_gasoline.predict(X_test)
# Out:
# 13/13 [==============================] - 0s 12ms/step

# %%
test_predictions = scaler_price.inverse_transform(test_predictions)
y_test = scaler_price.inverse_transform(y_test.reshape(-1, 1))

# %%
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
test_mape = calculate_mape(y_test, test_predictions)

print(f'Testing RMSE: {test_rmse:.2f}')
print(f'Testing MAPE: {test_mape:.2f}%')
# Out:
# Testing RMSE: 373.79
# Testing MAPE: 1.10%

# %%
dates = df_merged_gasoline.index.tolist()
test_dates = dates[-len(y_test):]

fig = go.Figure()
fig.add_trace(go.Scatter(x=test_dates, y=y_test.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=test_dates, y=test_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá xăng trên tập kiểm tra (mô hình LSTM, dữ liệu giá cam và giá xăng)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f880474d-7ecb-432b-a57c-dca0645d0035" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f880474d-7ecb-432b-a57c-dca0645d0035")) {                    Plotly.newPlot(                        "f880474d-7ecb-432b-a57c-dca0645d0035",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2023-03-30T00:00:00","2023-03-31T00:00:00","2023-04-01T00:00:00","2023-04-02T00:00:00","2023-04-03T00:00:00","2023-04-04T00:00:00","2023-04-05T00:00:00","2023-04-06T00:00:00","2023-04-07T00:00:00","2023-04-08T00:00:00","2023-04-09T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-15T00:00:00","2023-04-16T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-22T00:00:00","2023-04-23T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-04-29T00:00:00","2023-04-30T00:00:00","2023-05-01T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-06T00:00:00","2023-05-07T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-13T00:00:00","2023-05-14T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-20T00:00:00","2023-05-21T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-27T00:00:00","2023-05-28T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-03T00:00:00","2023-06-04T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-10T00:00:00","2023-06-11T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-17T00:00:00","2023-06-18T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-24T00:00:00","2023-06-25T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-29T00:00:00","2023-06-30T00:00:00","2023-07-01T00:00:00","2023-07-02T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00","2023-08-18T00:00:00","2023-08-19T00:00:00","2023-08-20T00:00:00","2023-08-21T00:00:00","2023-08-22T00:00:00","2023-08-23T00:00:00","2023-08-24T00:00:00","2023-08-25T00:00:00","2023-08-26T00:00:00","2023-08-27T00:00:00","2023-08-28T00:00:00","2023-08-29T00 ...

# %% [markdown]
# ### Đánh giá kết quả

# %%
results = pd.DataFrame({
    '': ['Train', 'Test'],
    'RMSE': [train_rmse, test_rmse],
    'MAPE (%)': [train_mape, test_mape]
})
results = results.round(2)

print(results)
# Out:
#             RMSE  MAPE (%)
# 0  Train  431.05      1.02
# 1   Test  373.79      1.10

# %% [markdown]
# ### Lưu mô hình

# %%
# model_gasoline.save('LSTM_gia_cam_xang.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
