# %% [markdown]
# # TRƯỜNG ĐẠI HỌC SƯ PHẠM KỸ THUẬT THÀNH PHỐ HỒ CHÍ MINH
# ## KHOA CÔNG NGHỆ THÔNG TIN
# ### BỘ MÔN KỸ THUẬT DỮ LIỆU
#
# # Đề tài:
# # ỨNG DỤNG PHƯƠNG PHÁP THỐNG KÊ VÀ HỌC MÁY ĐỂ DỰ ĐOÁN GIÁ NÔNG SẢN
#
# Sinh viên 1: Huỳnh Hạo Nhị - 20133006
#
# Sinh viên 2: Võ Hoài Thương - 20233012

# %% [markdown]
# # Thư viện

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout, Bidirectional
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Dữ liệu

# %% [markdown]
# ## Giá xoài

# %% [markdown]
# Dữ liệu giá xoài được thu thập của tỉnh An Giang, từ website của Viện Chính sách và Chiến lược Phát triển Nông nghiệp Nông thôn từ năm 2007 đến nay.
# *   date*: ngày
# *   price: giá xoài

# %%
df_mango = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/Xoai/gia_xoai.csv', encoding='ISO-8859-1')
df_mango.tail()
# Out:
#            date  price
# 3459  5/10/2024  25000
# 3460  5/11/2024  25000
# 3461  5/12/2024  25000
# 3462  5/13/2024  25000
# 3463  5/14/2024  25000

# %%
df_mango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3464 entries, 0 to 3463
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3464 non-null   object
#  1   price   3464 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 54.2+ KB

# %%
df_mango['date'] = pd.to_datetime(df_mango['date'])
df_mango.set_index('date', inplace=True)

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_mango, x=df_mango.index, y='price')
plt.title('Biểu đồ giá xoài tại An Giang')
plt.xlabel('Ngày')
plt.ylabel('Giá (đồng/kg)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Giá xăng

# %% [markdown]
# Dữ liệu giá xăng thu thập từ website của Công ty Dầu Việt Nam – CTCP.
# *   date*: ngày
# *   RON 95-III: giá xăng Ron 95-III

# %%
df_gasoline = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/Xang/gia_xang.csv', encoding='ISO-8859-1')
df_gasoline.tail()
# Out:
#            date  RON 95-III
# 170    2/5/2024       24.95
# 171    9/5/2024       23.54
# 172  16/05/2024       23.13
# 173  23/05/2024       23.21
# 174  29/05/2024       23.21

# %% [markdown]
# ### Xử lý outlier

# %%
df_gasoline[['RON 95-III']].boxplot()
# Out:
# <Axes: >

# %%
# Tính toán ngưỡng cho outlier sử dụng IQR
Q1 = df_gasoline['RON 95-III'].quantile(0.25)
Q3 = df_gasoline['RON 95-III'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Xác định các dòng dữ liệu có giá trị nằm ngoài ngưỡng
outliers = df_gasoline[(df_gasoline['RON 95-III'] < lower_bound) | (df_gasoline['RON 95-III'] > upper_bound)]
print("Số lượng outlier:", len(outliers))
# Out:
# Số lượng outlier: 14

# %%
# Kiểm tra và thay đổi giá trị nếu nó nằm ngoài ngưỡng
df_gasoline.at[df_gasoline.index[0], 'RON 95-III'] = min(max(df_gasoline.iloc[0]['RON 95-III'], lower_bound), upper_bound)

# Thay thế giá trị của outlier bằng giá trị trước đó
for index, row in outliers.iterrows():
    previous_date_index = df_gasoline.index.get_loc(index) - 1
    if previous_date_index >= 0:
        previous_date = df_gasoline.index[previous_date_index]
        previous_value = df_gasoline.loc[previous_date, 'RON 95-III']
        df_gasoline.at[index, 'RON 95-III'] = previous_value

# %%
df_gasoline[['RON 95-III']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### Fill dữ liệu ngày bị thiếu

# %%
df_gasoline['date'] = pd.to_datetime(df_gasoline['date'])
df_gasoline.set_index('date', inplace=True)
# Out:
# <ipython-input-12-2ca4586e2886>:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_gasoline['date'] = pd.to_datetime(df_gasoline['date'])

# %%
idx = pd.date_range(df_gasoline.index.min(), df_gasoline.index.max())
df_gasoline = df_gasoline.reindex(idx)
df_gasoline.fillna(method='ffill', inplace=True)

# %% [markdown]
# ### Merge dữ liệu xăng với xoài

# %%
start_date = df_gasoline.index.min()
df_orange_filtered = df_mango.loc[start_date:]

df_merged_gasoline = pd.merge(df_orange_filtered, df_gasoline[['RON 95-III']], left_index=True, right_index=True, how='left')
df_merged_gasoline['RON 95-III'] = df_merged_gasoline['RON 95-III'].ffill()

print(df_merged_gasoline.tail())
# Out:
#             price  RON 95-III
# date
# 2024-05-10  25000       23.54
# 2024-05-11  25000       23.54
# 2024-05-12  25000       23.54
# 2024-05-13  25000       23.54
# 2024-05-14  25000       23.54

# %%
correlation_matrix = df_merged_gasoline.corr()

plt.figure(figsize=(6, 6), dpi=75)
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", linewidths=.5, cmap='coolwarm', center=0)
plt.title('Biểu đồ nhiệt ma trận tương quan')
plt.show()

# %%
# df_merged_gasoline.to_csv('coffee_gasoline.csv', index=True)

# %% [markdown]
# ### Làm mịn dữ liệu

# %%
df_merged_gasoline = df_merged_gasoline.rolling(window=30, min_periods=1).mean()

# %% [markdown]
# # Mô hình BiLSTM dự đoán

# %% [markdown]
# Mạng Bidirectional Long Short-Term Memory (BiLSTM) là biến thể từ mạng LSTM, nó là sự kết hợp của hai lớp LSTM chạy song song ngược hướng trong cùng một chuỗi dữ liệu thời gian, một lớp LSTM chạy xuôi từ đầu đến cuối chuỗi dữ liệu và một lớp LSTM chạy ngược từ cuối về đầu chuỗi dữ liệu. Bởi vì mô hình BiLSTM xử lý thông tin cả hai hướng của chuỗi dữ liệu nên nó có thể hiểu được ngữ cảnh từ hai hướng, giúp tăng khả năng phân tích, xử lý.
#
# ![bilstm (1).png](data:image/png;base64,...)

# %% [markdown]
# ## Giá cà phê kết hợp giá xăng

# %% [markdown]
# ### Xây dựng mô hình

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), :])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# Preprocess data
scaler_price = MinMaxScaler(feature_range=(0, 1))
scaled_price = scaler_price.fit_transform(df_merged_gasoline[['price']])

scaler_export = MinMaxScaler(feature_range=(0, 1))
scaled_export = scaler_export.fit_transform(df_merged_gasoline[['RON 95-III']])

scaled_data = np.concatenate((scaled_price, scaled_export), axis=1)

# %%
seq_length = 30
X, y = create_sequences(scaled_data, seq_length)

# %%
X.shape, y.shape
# Out:
# ((2063, 30, 2), (2063,))

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print("Kích thước tập huấn luyện:", X_train.shape, y_train.shape)
print("Kích thước tập kiểm tra:", X_test.shape, y_test.shape)
# Out:
# Kích thước tập huấn luyện: (1650, 30, 2) (1650,)
# Kích thước tập kiểm tra: (413, 30, 2) (413,)

# %%
model_gasoline = Sequential()
# model_gasoline.add(Bidirectional(LSTM(units=128, return_sequences=True), input_shape=(seq_length, 2)))
model_gasoline.add(Bidirectional(LSTM(units=128), input_shape=(seq_length, 2)))
model_gasoline.add(Dropout(0.2))
model_gasoline.add(Dense(units=64, activation='tanh'))
model_gasoline.add(Dense(units=1))

# %%
model_gasoline.compile(optimizer='adam', loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# %%
model_gasoline.fit(X_train, y_train, epochs=50, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 26/26 [==============================] - 15s 90ms/step - loss: 0.0303
# Epoch 2/50
# 26/26 [==============================] - 3s 109ms/step - loss: 0.0052
# Epoch 3/50
# 26/26 [==============================] - 3s 132ms/step - loss: 0.0031
# Epoch 4/50
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0023
# Epoch 5/50
# 26/26 [==============================] - 2s 88ms/step - loss: 0.0018
# Epoch 6/50
# 26/26 [==============================] - 2s 88ms/step - loss: 0.0015
# Epoch 7/50
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0013
# Epoch 8/50
# 26/26 [==============================] - 4s 155ms/step - loss: 0.0012
# Epoch 9/50
# 26/26 [==============================] - 2s 90ms/step - loss: 9.8863e-04
# Epoch 10/50
# 26/26 [==============================] - 2s 87ms/step - loss: 8.9936e-04
# Epoch 11/50
# 26/26 [==============================] - 2s 88ms/step - loss: 8.7977e-04
# Epoch 12/50
# 26/26 [==============================] - 2s 88ms/step - loss: 8.7169e-04
# Epoch 13/50
# 26/26 [==============================] - 3s 123ms/step - loss: 7.9087e-04
# Epoch 14/50
# 26/26 [==============================] - 3s 118ms/step - loss: 7.2282e-04
# Epoch 15/50
# 26/26 [==============================] - 2s 87ms/step - loss: 7.1167e-04
# Epoch 16/50
# 26/26 [==============================] - 2s 89ms/step - loss: 6.6657e-04
# Epoch 17/50
# 26/26 [==============================] - 2s 87ms/step - loss: 5.6331e-04
# Epoch 18/50
# 26/26 [==============================] - 3s 106ms/step - loss: 6.3230e-04
# Epoch 19/50
# 26/26 [==============================] - 4s 146ms/step - loss: 6.8810e-04
# Epoch 20/50
# 26/26 [==============================] - 2s 86ms/step - loss: 5.7153e-04
# Epoch 21/50
# 26/26 [==============================] - 2s 86ms/step - loss: 5.8889e-04
# Epoch 22/50
# 26/26 [==============================] - 2s 88ms/step - loss: 5.5072e-04
# Epoch 23/50
# 26/26 [==============================] - 2s 87ms/step - loss: 5.2105e-04
# Epoch 24/50
# 26/26 [==============================] - 4s 145ms/step - loss: 4.6242e-04
# Epoch 25/50
# 26/26 [==============================] - 3s 106ms/step - loss: 4.8773e-04
# Epoch 26/50
# 26/26 [==============================] - 2s 87ms/step - loss: 4.9492e-04
# Epoch 27/50
# 26/26 [==============================] - 2s 86ms/step - loss: 4.6934e-04
# Epoch 28/50
# 26/26 [==============================] - 2s 88ms/step - loss: 4.9077e-04
# Epoch 29/50
# 26/26 [==============================] - 3s 107ms/step - loss: 4.4151e-04
# Epoch 30/50
# 26/26 [==============================] - 4s 137ms/step - loss: 5.2308e-04
# Epoch 31/50
# 26/26 [==============================] - 2s 89ms/step - loss: 5.0832e-04
# Epoch 32/50
# 26/26 [==============================] - 2s 89ms/step - loss: 4.5971e-04
# Epoch 33/50
# 26/26 [==============================] - 2s 88ms/step - loss: 3.7715e-04
# Epoch 34/50
# 26/26 [==============================] - 2s 88ms/step - loss: 3.6406e-04
# Epoch 35/50
# 26/26 [==============================] - 4s 160ms/step - loss: 3.8868e-04
# Epoch 36/50
# 26/26 [==============================] - 2s 87ms/step - loss: 4.6308e-04
# Epoch 37/50
# 26/26 [==============================] - 2s 88ms/step - loss: 4.4445e-04
# Epoch 38/50
# 26/26 [==============================] - 2s 91ms/step - loss: 4.0325e-04
# Epoch 39/50
# 26/26 [==============================] - 2s 89ms/step - loss: 4.5067e-04

# %% [markdown]
# ### Dự đoán trên tập train

# %%
train_predictions = model_gasoline.predict(X_train)
# Out:
# 52/52 [==============================] - 2s 22ms/step

# %%
train_predictions = scaler_price.inverse_transform(train_predictions)
y_train = scaler_price.inverse_transform(y_train.reshape(-1, 1))

# %%
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_mape = calculate_mape(y_train, train_predictions)

print(f'Training RMSE: {train_rmse:.2f}')
print(f'Training MAPE: {train_mape:.2f}%')
# Out:
# Training RMSE: 347.57
# Training MAPE: 1.02%

# %%
dates = df_merged_gasoline.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_train)], y=y_train.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(train_predictions)], y=train_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá xoài trên tập huấn luyện (mô hình BiLSTM, dữ liệu giá xoài và giá xăng)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8f8ede64-f8a0-4498-9395-b9ec1557256e" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f8ede64-f8a0-4498-9395-b9ec1557256e")) {                    Plotly.newPlot(                        "8f8ede64-f8a0-4498-9395-b9ec1557256e",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2018-08-22T00:00:00","2018-08-23T00:00:00","2018-08-24T00:00:00","2018-08-25T00:00:00","2018-08-26T00:00:00","2018-08-27T00:00:00","2018-08-28T00:00:00","2018-08-29T00:00:00","2018-08-30T00:00:00","2018-08-31T00:00:00","2018-09-01T00:00:00","2018-09-02T00:00:00","2018-09-03T00:00:00","2018-09-04T00:00:00","2018-09-05T00:00:00","2018-09-06T00:00:00","2018-09-07T00:00:00","2018-09-08T00:00:00","2018-09-09T00:00:00","2018-09-10T00:00:00","2018-09-11T00:00:00","2018-09-12T00:00:00","2018-09-13T00:00:00","2018-09-14T00:00:00","2018-09-15T00:00:00","2018-09-16T00:00:00","2018-09-17T00:00:00","2018-09-18T00:00:00","2018-09-19T00:00:00","2018-09-20T00:00:00","2018-09-21T00:00:00","2018-09-22T00:00:00","2018-09-23T00:00:00","2018-09-24T00:00:00","2018-09-25T00:00:00","2018-09-26T00:00:00","2018-09-27T00:00:00","2018-09-28T00:00:00","2018-09-29T00:00:00","2018-09-30T00:00:00","2018-10-01T00:00:00","2018-10-02T00:00:00","2018-10-03T00:00:00","2018-10-04T00:00:00","2018-10-05T00:00:00","2018-10-06T00:00:00","2018-10-07T00:00:00","2018-10-08T00:00:00","2018-10-09T00:00:00","2018-10-10T00:00:00","2018-10-11T00:00:00","2018-10-12T00:00:00","2018-10-13T00:00:00","2018-10-14T00:00:00","2018-10-15T00:00:00","2018-10-16T00:00:00","2018-10-17T00:00:00","2018-10-18T00:00:00","2018-10-19T00:00:00","2018-10-20T00:00:00","2018-10-21T00:00:00","2018-10-22T00:00:00","2018-10-23T00:00:00","2018-10-24T00:00:00","2018-10-25T00:00:00","2018-10-26T00:00:00","2018-10-27T00:00:00","2018-10-28T00:00:00","2018-10-29T00:00:00","2018-10-30T00:00:00","2018-10-31T00:00:00","2018-11-01T00:00:00","2018-11-02T00:00:00","2018-11-03T00:00:00","2018-11-04T00:00:00","2018-11-05T00:00:00","2018-11-06T00:00:00","2018-11-07T00:00:00","2018-11-08T00:00:00","2018-11-09T00:00:00","2018-11-10T00:00:00","2018-11-11T00:00:00","2018-11-12T00:00:00","2018-11-13T00:00:00","2018-11-14T00:00:00","2018-11-15T00:00:00","2018-11-16T00:00:00","2018-11-17T00:00:00","2018-11-18T00:00:00","2018-11-19T00:00:00","2018-11-20T00:00:00","2018-11-21T00:00:00","2018-11-22T00:00:00","2018-11-23T00:00:00","2018-11-24T00:00:00","2018-11-25T00:00:00","2018-11-26T00:00:00","2018-11-27T00:00:00","2018-11-28T00:00:00","2018-11-29T00:00:00","2018-11-30T00:00:00","2018-12-01T00:00:00","2018-12-02T00:00:00","2018-12-03T00:00:00","2018-12-04T00:00:00","2018-12-05T00:00:00","2018-12-06T00:00:00","2018-12-07T00:00:00","2018-12-08T00:00:00","2018-12-09T00:00:00","2018-12-10T00:00:00","2018-12-11T00:00:00","2018-12-12T00:00:00","2018-12-13T00:00:00","2018-12-14T00:00:00","2018-12-15T00:00:00","2018-12-16T00:00:00","2018-12-17T00:00:00","2018-12-18T00:00:00","2018-12-19T00:00:00","2018-12-20T00:00:00","2018-12-21T00:00:00","2018-12-22T00:00:00","2018-12-23T00:00:00","2018-12-24T00:00:00","2018-12-25T00:00:00","2018-12-26T00:00:00","2018-12-27T00:00:00","2018-12-28T00:00:00","2018-12-29T00:00:00","2018-12-30T00:00:00","2018-12-31T00:00:00","2019-01-01T00:00:00","2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-05T00:00:00","2019-01-06T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-12T00:00:00","2019-01-13T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-19T00:00:00","2019-01-20T00:00:00","2019-01-21T00 ...

# %% [markdown]
# ### Dự đoán trên tập test

# %%
test_predictions = model_gasoline.predict(X_test)
# Out:
# 13/13 [==============================] - 0s 22ms/step

# %%
test_predictions = scaler_price.inverse_transform(test_predictions)
y_test = scaler_price.inverse_transform(y_test.reshape(-1, 1))

# %%
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
test_mape = calculate_mape(y_test, test_predictions)

print(f'Testing RMSE: {test_rmse:.2f}')
print(f'Testing MAPE: {test_mape:.2f}%')
# Out:
# Testing RMSE: 224.34
# Testing MAPE: 0.58%

# %%
dates = df_merged_gasoline.index.tolist()
test_dates = dates[-len(y_test):]

fig = go.Figure()
fig.add_trace(go.Scatter(x=test_dates, y=y_test.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=test_dates, y=test_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá xoài trên tập kiểm tra (mô hình BiLSTM, dữ liệu giá xoài và giá xăng)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1f4eabff-b119-475d-8d60-630cf95ecc17" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f4eabff-b119-475d-8d60-630cf95ecc17")) {                    Plotly.newPlot(                        "1f4eabff-b119-475d-8d60-630cf95ecc17",                        [{"line":{"width":2},"mode":"lines","name":"Gi\u00e1 th\u1ef1c t\u1ebf","x":["2023-03-29T00:00:00","2023-03-30T00:00:00","2023-03-31T00:00:00","2023-04-01T00:00:00","2023-04-02T00:00:00","2023-04-03T00:00:00","2023-04-04T00:00:00","2023-04-05T00:00:00","2023-04-06T00:00:00","2023-04-07T00:00:00","2023-04-08T00:00:00","2023-04-09T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-15T00:00:00","2023-04-16T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-22T00:00:00","2023-04-23T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-04-29T00:00:00","2023-04-30T00:00:00","2023-05-01T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-06T00:00:00","2023-05-07T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-13T00:00:00","2023-05-14T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-20T00:00:00","2023-05-21T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-27T00:00:00","2023-05-28T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-03T00:00:00","2023-06-04T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-10T00:00:00","2023-06-11T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-17T00:00:00","2023-06-18T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-24T00:00:00","2023-06-25T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-29T00:00:00","2023-06-30T00:00:00","2023-07-01T00:00:00","2023-07-02T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-29T00:00:00","2023-07-30T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00:00","2023-08-03T00:00:00","2023-08-04T00:00:00","2023-08-05T00:00:00","2023-08-06T00:00:00","2023-08-07T00:00:00","2023-08-08T00:00:00","2023-08-09T00:00:00","2023-08-10T00:00:00","2023-08-11T00:00:00","2023-08-12T00:00:00","2023-08-13T00:00:00","2023-08-14T00:00:00","2023-08-15T00:00:00","2023-08-16T00:00:00","2023-08-17T00:00:00","2023-08-18T00:00:00","2023-08-19T00:00:00","2023-08-20T00:00:00","2023-08-21T00:00:00","2023-08-22T00:00:00","2023-08-23T00:00:00","2023-08-24T00:00:00","2023-08-25T00:00:00","2023-08-26T00:00:00","2023-08-27T00:00:00","2023-08-28T00 ...

# %% [markdown]
# ### Đánh giá kết quả

# %%
results = pd.DataFrame({
    '': ['Train', 'Test'],
    'RMSE': [train_rmse, test_rmse],
    'MAPE (%)': [train_mape, test_mape]
})
results = results.round(2)

print(results)
# Out:
#             RMSE  MAPE (%)
# 0  Train  347.57      1.02
# 1   Test  224.34      0.58

# %% [markdown]
# ### Lưu mô hình

# %%
# model_gasoline.save('BiLSTM_gia_xoai_xang.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
