# %% [markdown]
# # TRƯỜNG ĐẠI HỌC SƯ PHẠM KỸ THUẬT THÀNH PHỐ HỒ CHÍ MINH
# ## KHOA CÔNG NGHỆ THÔNG TIN
# ### BỘ MÔN KỸ THUẬT DỮ LIỆU
#
# # Đề tài:
# # ỨNG DỤNG PHƯƠNG PHÁP THỐNG KÊ VÀ HỌC MÁY ĐỂ DỰ ĐOÁN GIÁ NÔNG SẢN
#
# Sinh viên 1: Huỳnh Hạo Nhị - 20133006
#
# Sinh viên 2: Võ Hoài Thương - 20233012

# %% [markdown]
# # Thư viện

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Dữ liệu giá xoài

# %% [markdown]
# Dữ liệu giá xoài được thu thập của tỉnh An Giang, từ website của Viện Chính sách và Chiến lược Phát triển Nông nghiệp Nông thôn từ năm 2007 đến nay.
# *   date*: ngày
# *   price: giá xoài

# %%
df_mango = pd.read_csv('https://raw.githubusercontent.com/thuongh2/FinalProject/main/data_final/Xoai/gia_xoai.csv', encoding='ISO-8859-1')
df_mango.tail()
# Out:
#             date  price
# 1416  2024-05-06  30000
# 1417  2024-05-08  25000
# 1418  2024-05-10  25000
# 1419  2024-05-13  25000
# 1420  2024-05-14  25000

# %%
df_mango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1421 entries, 0 to 1420
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1421 non-null   object
#  1   price   1421 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 22.3+ KB

# %%
df_mango['date'] = pd.to_datetime(df_mango['date'])
df_mango.set_index('date', inplace=True)

# %% [markdown]
# ## Điền dữ liệu ngày còn thiếu

# %%
df_mango.shape
# Out:
# (1421, 1)

# %%
idx = pd.date_range(df_mango.index.min(), df_mango.index.max())
df_mango = df_mango.reindex(idx)
df_mango.fillna(method='ffill', inplace=True)
df_mango.tail()
# Out:
#               price
# 2024-05-10  25000.0
# 2024-05-11  25000.0
# 2024-05-12  25000.0
# 2024-05-13  25000.0
# 2024-05-14  25000.0

# %%
df_mango.shape
# Out:
# (3464, 1)

# %%
# df_mango.to_csv('gia_xoai.csv', index=True)

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_mango, x=df_mango.index, y='price')
plt.title('Biểu đồ giá xoài tại An Giang')
plt.xlabel('Ngày')
plt.ylabel('Giá (đồng/kg)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Làm mịn dữ liệu

# %%
df_mango = df_mango.rolling(window=30, min_periods=1).mean()

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_mango, x=df_mango.index, y='price')
plt.title('Biểu đồ giá xoài tại An Giang (đã được làm mịn)')
plt.xlabel('Ngày')
plt.ylabel('Giá (đồng/kg)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Mô hình lSTM dự đoán đơn biến

# %% [markdown]
# Mạng LSTM (Long Short-Term Memory) là mạng nơ-ron hồi quy có khả năng xử lý chuỗi thời gian dài hạn với cấu trúc gồm ba cổng:
# *   Cổng quên (f): xác định thông tin nào của trạng thái tạm thời cũ được lưu trữ hoặc loại bỏ bằng hàm sigmoid.
# *   Cổng nhập (i): xác định thông tin được thêm vào trạng thái tạm thời bằng hàm sigmoid.
# *   Cổng xuất (o): xác định thông tin được xuất làm đầu ra của mạng LSTM hàm sigmoid.
# ![lstm (2).png](data:image/png;base64,...)

# %% [markdown]
# ## Xây dựng mô hình

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length)])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_price = scaler.fit_transform(df_mango['price'].values.reshape(-1, 1))

# %%
seq_length = 30
X, y = create_sequences(scaled_price, seq_length)

# %%
X.shape, y.shape
# Out:
# ((3434, 30, 1), (3434, 1))

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print("Kích thước tập huấn luyện:", X_train.shape, y_train.shape)
print("Kích thước tập kiểm tra:", X_test.shape, y_test.shape)
# Out:
# Kích thước tập huấn luyện: (2747, 30, 1) (2747, 1)
# Kích thước tập kiểm tra: (687, 30, 1) (687, 1)

# %%
model = Sequential()
model.add(LSTM(units=128, return_sequences=True, input_shape=(seq_length, 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=64))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# %%
model.fit(X_train, y_train, epochs=50, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 43/43 [==============================] - 14s 124ms/step - loss: 0.0217
# Epoch 2/50
# 43/43 [==============================] - 4s 81ms/step - loss: 0.0029
# Epoch 3/50
# 43/43 [==============================] - 3s 82ms/step - loss: 0.0022
# Epoch 4/50
# 43/43 [==============================] - 4s 93ms/step - loss: 0.0019
# Epoch 5/50
# 43/43 [==============================] - 5s 105ms/step - loss: 0.0018
# Epoch 6/50
# 43/43 [==============================] - 4s 84ms/step - loss: 0.0018
# Epoch 7/50
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0018
# Epoch 8/50
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0016
# Epoch 9/50
# 43/43 [==============================] - 3s 81ms/step - loss: 0.0017
# Epoch 10/50
# 43/43 [==============================] - 4s 83ms/step - loss: 0.0015
# Epoch 11/50
# 43/43 [==============================] - 5s 107ms/step - loss: 0.0015
# Epoch 12/50
# 43/43 [==============================] - 4s 97ms/step - loss: 0.0014
# Epoch 13/50
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0013
# Epoch 14/50
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0013
# Epoch 15/50
# 43/43 [==============================] - 5s 123ms/step - loss: 0.0013
# Epoch 16/50
# 43/43 [==============================] - 3s 81ms/step - loss: 0.0012
# Epoch 17/50
# 43/43 [==============================] - 3s 81ms/step - loss: 0.0015
# Epoch 18/50
# 43/43 [==============================] - 5s 113ms/step - loss: 0.0013
# Epoch 19/50
# 43/43 [==============================] - 4s 85ms/step - loss: 0.0012
# Epoch 20/50
# 43/43 [==============================] - 4s 83ms/step - loss: 0.0011
# Epoch 21/50
# 43/43 [==============================] - 4s 96ms/step - loss: 0.0011
# Epoch 22/50
# 43/43 [==============================] - 5s 110ms/step - loss: 0.0011
# Epoch 23/50
# 43/43 [==============================] - 3s 81ms/step - loss: 0.0011
# Epoch 24/50
# 43/43 [==============================] - 4s 84ms/step - loss: 0.0011
# Epoch 25/50
# 43/43 [==============================] - 5s 122ms/step - loss: 0.0012
# Epoch 26/50
# 43/43 [==============================] - 4s 95ms/step - loss: 9.9679e-04
# Epoch 27/50
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0011
# Epoch 28/50
# 43/43 [==============================] - 5s 114ms/step - loss: 0.0011
# Epoch 29/50
# 43/43 [==============================] - 5s 111ms/step - loss: 9.6787e-04
# Epoch 30/50
# 43/43 [==============================] - 4s 84ms/step - loss: 0.0010
# Epoch 31/50
# 43/43 [==============================] - 4s 99ms/step - loss: 9.7139e-04
# Epoch 32/50
# 43/43 [==============================] - 5s 105ms/step - loss: 9.2789e-04
# Epoch 33/50
# 43/43 [==============================] - 4s 82ms/step - loss: 0.0011
# Epoch 34/50
# 43/43 [==============================] - 4s 83ms/step - loss: 0.0011
# Epoch 35/50
# 43/43 [==============================] - 5s 124ms/step - loss: 8.5706e-04
# Epoch 36/50
# 43/43 [==============================] - 4s 82ms/step - loss: 9.1135e-04
# Epoch 37/50
# 43/43 [==============================] - 4s 82ms/step - loss: 9.0744e-04
# Epoch 38/50
# 43/43 [==============================] - 6s 137ms/step - loss: 9.3209e-04
# Epoch 39/50
# 43/43 [==============================] - 7s 168ms/step - loss: 9.1383e-04
# Epoch 40/50
# 43/43 [==============================] - 9s 206ms/step - loss: 8.0432e-04
# Epoch 41/50
# 43/43 [==============================] - 7s 171ms/step - loss: 7.8052e-04
# Epoch 42/50
# 43/43 [==============================] - 6s 143ms/step - loss: 8.3512e-04
# Epoch 43/50
# 43/43 [==============================] - 4s 82ms/step - loss: 8.3000e-04
# Epoch 44/50
# 43/43 [==============================] - 4s 82ms/step - loss: 7.7716e-04
# Epoch 45/50
# 43/43 [==============================] - 5s 115ms/step - loss: 8.2891e-04
# Epoch 46/50
# 20/43 [============>.................] - ETA: 2s - loss: 8.4428e-04

# %% [markdown]
# ## Dự đoán tập train

# %%
train_predictions = model.predict(X_train)

# %%
train_predictions = scaler.inverse_transform(train_predictions)
y_train = scaler.inverse_transform(y_train)

# %%
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
train_mape = calculate_mape(y_train, train_predictions)

print(f'Training RMSE: {train_rmse:.2f}')
print(f'Training MAPE: {train_mape:.2f}%')

# %%
dates = df_mango.index.tolist()

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates[:len(y_train)], y=y_train.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=dates[:len(train_predictions)], y=train_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá xoài trên tập huấn luyện (mô hình LSTM)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()

# %% [markdown]
# ## Dự đoán tập test

# %%
test_predictions = model.predict(X_test)

# %%
test_predictions = scaler.inverse_transform(test_predictions)
y_test = scaler.inverse_transform(y_test)

# %%
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
test_mape = calculate_mape(y_test, test_predictions)

print(f'Testing RMSE: {test_rmse:.2f}')
print(f'Testing MAPE: {train_mape:.2f}%')

# %%
dates = df_mango.index.tolist()
test_dates = dates[-len(y_test):]

fig = go.Figure()
fig.add_trace(go.Scatter(x=test_dates, y=y_test.flatten(), mode='lines', name='Giá thực tế', line=dict(width=2)))
fig.add_trace(go.Scatter(x=test_dates, y=test_predictions.flatten(), mode='lines', name='Giá dự đoán', line=dict(color='orange', width=2)))

fig.update_layout(
    title={
        'text': 'Biểu đồ dự đoán giá xoài trên tập kiểm tra (mô hình LSTM)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title='Ngày',
    yaxis_title='Giá (đồng/kg)',
    xaxis_tickangle=45,
    width=1200,
    height=600
)

fig.show()

# %% [markdown]
# ## Đánh giá kết quả

# %%
results = pd.DataFrame({
    '': ['Train', 'Test'],
    'RMSE': [train_rmse, test_rmse],
    'MAPE (%)': [train_mape, test_mape]
})
results = results.round(2)

print(results)

# %% [markdown]
# ## Lưu mô hình

# %%
# model.save('LSTM_gia_xoai.h5')
